# %%
# LB Score = 0.83793

# version 1.3
# Added Total damage feature

# %%
from scipy.sparse import hstack
import time
import lightgbm as lgb
import pandas as pd
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
import seaborn as sns
from matplotlib import pyplot as plt
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import TimeSeriesSplit, cross_val_score, GridSearchCV, StratifiedKFold, KFold
from sklearn.preprocessing import StandardScaler
import ujson as json
from tqdm import tqdm_notebook

# %%
def prepare_submit(model, x_test, file_name = 'submission'):
    y_test_pred= model.predict_proba(X_test)[:, 1]
    df_submission = pd.DataFrame({'radiant_win_prob': y_test_pred}, 
                                 index=df_test_features.index)
    df_submission.to_csv(file_name)

# %%
def train_model(X, X_test, y, params, folds, model_type='lgb', plot_feature_importance=False, averaging='usual', model=None, silent = False):
    oof = np.zeros(len(X))
    prediction = np.zeros(len(X_test))
    scores = []
    feature_importance = pd.DataFrame()
    for fold_n, (train_index, valid_index) in enumerate(folds.split(X, y)):
        if (not silent) : print('Fold', fold_n, 'started at', time.ctime())
        X_train, X_valid = X.loc[train_index], X.loc[valid_index]
        y_train, y_valid = y[train_index], y[valid_index]
        
        if model_type == 'lgb':
            train_data = lgb.Dataset(X_train, label=y_train)
            valid_data = lgb.Dataset(X_valid, label=y_valid)
            
            model = lgb.train(params,
                    train_data,
                    num_boost_round=20000,
                    valid_sets = [train_data, valid_data],
                    verbose_eval=1000,
                    early_stopping_rounds = 2000)
            
            y_pred_valid = model.predict(X_valid)
            y_pred = model.predict(X_test, num_iteration=model.best_iteration)
            
        
            
        oof[valid_index] = y_pred_valid.reshape(-1,)
        scores.append(roc_auc_score(y_valid, y_pred_valid))

        if averaging == 'usual':
            prediction += y_pred
        elif averaging == 'rank':
            prediction += pd.Series(y_pred).rank().values  
        
        if model_type == 'lgb':
            # feature importance
            fold_importance = pd.DataFrame()
            fold_importance["feature"] = X.columns
            fold_importance["importance"] = model.feature_importance()
            fold_importance["fold"] = fold_n + 1
            feature_importance = pd.concat([feature_importance, fold_importance], axis=0)

    prediction /= n_fold
    
    print('CV mean score: {0:.4f}, std: {1:.4f}.'.format(np.mean(scores), np.std(scores)))
    CV_scores = np.mean(scores)
    if model_type == 'lgb':
        feature_importance["importance"] /= n_fold
        if plot_feature_importance:
            cols = feature_importance[["feature", "importance"]].groupby("feature").mean().sort_values(
                by="importance", ascending=False)[:20].index

            best_features = feature_importance.loc[feature_importance.feature.isin(cols)]

            plt.figure(figsize=(16, 10));
            sns.barplot(x="importance", y="feature", data=best_features.sort_values(by="importance", ascending=False));
            plt.title('LGB Features (avg over folds)');
        
            return oof, prediction, feature_importance, CV_scores
        return oof, prediction, scores, CV_scores
    
    else:
        return oof, prediction, scores, CV_scores

# %%
train = pd.read_csv('../data/train_features.csv', index_col='match_id_hash')
target = pd.read_csv('../data/train_targets.csv', index_col='match_id_hash')
test = pd.read_csv('../data/test_features.csv', index_col='match_id_hash')

# %%
split_index = train.shape[0]

# %%
df = pd.concat([train, test], sort=False)

# %%
df.shape
# Out:
# (49675, 245)

# %%
new_features = pd.DataFrame()

# %%
r_kills_columns = [col for col in df if col.endswith('kills')][:5]
d_kills_columns = [col for col in df if col.endswith('kills')][5:]
new_features['r_kills_mean'] = df[r_kills_columns].mean(axis = 1)
new_features['r_kills_std'] = df[r_kills_columns].std(axis = 1)
new_features['r_kills_total'] = df[r_kills_columns].sum(axis = 1)
new_features['d_kills_mean'] = df[d_kills_columns].mean(axis = 1)
new_features['d_kills_std'] = df[d_kills_columns].std(axis = 1)
new_features['d_kills_total'] = df[d_kills_columns].sum(axis = 1)
new_features['kills_diff'] = new_features['d_kills_total'] - new_features['r_kills_total']

# %%
r_gold_columns = [col for col in df if col.endswith('gold')][:5]
d_gold_columns = [col for col in df if col.endswith('gold')][5:]
new_features['r_gold_mean'] = df[r_gold_columns].mean(axis = 1)
new_features['r_gold_std'] = df[r_gold_columns].std(axis = 1)
new_features['r_gold_total'] = df[r_gold_columns].sum(axis = 1)
new_features['d_gold_mean'] = df[d_gold_columns].mean(axis = 1)
new_features['d_gold_std'] = df[d_gold_columns].std(axis = 1)
new_features['d_gold_total'] = df[d_gold_columns].sum(axis = 1)
#new_features['gold_prop'] = new_features['d_gold_total'] / new_features['r_gold_total']
new_features['gold_prop1'] = new_features['r_gold_total'] / new_features['d_gold_total']

# %%
r_stuns_columns = [col for col in df if col.endswith('stuns')][:5]
d_stuns_columns = [col for col in df if col.endswith('stuns')][5:]
new_features['r_stuns_total'] = df[r_stuns_columns].sum(axis = 1) + 1
new_features['d_stuns_total'] = df[d_stuns_columns].sum(axis = 1) + 1

# %%
r_max_health_columns = [col for col in df if col.endswith('max_health')][:5]
d_max_health_columns = [col for col in df if col.endswith('max_health')][5:]
new_features['d_max_health_total'] = df[r_max_health_columns].sum(axis = 1)
new_features['r_max_health_total'] = df[d_max_health_columns].sum(axis = 1)
new_features['max_health_prop'] = new_features['r_max_health_total'] / new_features['d_max_health_total']

# %%
r_max_mana_columns = [col for col in df if col.endswith('max_mana')][:5]
d_max_mana_columns = [col for col in df if col.endswith('max_mana')][5:]
new_features['d_max_mana_total'] = df[r_max_mana_columns].sum(axis = 1)
new_features['r_max_mana_total'] = df[d_max_mana_columns].sum(axis = 1)
new_features['max_mana_prop'] = new_features['r_max_mana_total'] / new_features['d_max_mana_total']

# %%
new_features['d_xp_total'] = df[[col for col in df if col.endswith('xp')][:5]].sum(axis = 1) + 1
new_features['r_xp_total'] = df[[col for col in df if col.endswith('xp')][5:]].sum(axis = 1) + 1

# %%
new_features['d_xp_std'] = df[[col for col in df if col.endswith('xp')][:5]].std(axis = 1)
new_features['r_xp_std'] = df[[col for col in df if col.endswith('xp')][5:]].std(axis = 1)

# %%
#new_features['total_xp_ratio'] = new_features['d_xp_total'] / new_features['r_xp_total']
new_features['total_xp_ratio1'] = new_features['r_xp_total'] / new_features['d_xp_total']

# %%
new_features['d_obs_total'] = df[[col for col in df if col.endswith('obs_placed')][:5]].sum(axis = 1)
new_features['r_obs_total'] = df[[col for col in df if col.endswith('obs_placed')][5:]].sum(axis = 1)
#new_features['obs_prop'] = new_features['d_obs_total']/ new_features['r_obs_total']

# %%
r_towers_killed_columns = [col for col in df if col.endswith('towers_killed')][:5]
d_towers_killed_columns = [col for col in df if col.endswith('towers_killed')][5:]
new_features['d_towers'] = df[d_towers_killed_columns].sum(axis = 1) + 1
new_features['r_towers'] = df[r_towers_killed_columns].sum(axis = 1) + 1
new_features['towers_prop'] = new_features['d_towers'] / new_features['r_towers']

# %%
r_level_columns = [col for col in df if col.endswith('level')][:5]
d_level_columns = [col for col in df if col.endswith('level')][5:]
new_features['r_max_level'] = df[r_level_columns].max(axis = 1)
new_features['d_max_level'] = df[d_level_columns].max(axis = 1)
new_features['max_level_prop'] = new_features['d_max_level'] / new_features['r_max_level']

# %%
new_features['r_mean_level'] = df[r_level_columns].mean(axis = 1)
new_features['d_mean_level'] = df[d_level_columns].mean(axis = 1)
#new_features['mean_level_prop'] = new_features['r_mean_level'] / new_features['d_mean_level']

# %%
new_features['r_min_level'] = df[r_level_columns].min(axis = 1)
new_features['d_min_level'] = df[d_level_columns].min(axis = 1)
#new_features['min_level_prop'] = new_features['r_min_level'] / new_features['d_min_level']

# %%
r_roshans_killes_columns = [col for col in df if col.endswith('roshans_killed')][:5]
d_roshans_killes_columns = [col for col in df if col.endswith('roshans_killed')][5:]
new_features['r_roshans'] = df[r_roshans_killes_columns].sum(axis = 1) + 1
new_features['d_roshans'] = df[d_roshans_killes_columns].sum(axis = 1) + 1
#new_features['roshans_prop'] = new_features['r_roshans'] / new_features['d_roshans']

# %%
r_x_columns = [col for col in df if col.endswith('x')][:5]
d_x_columns = [col for col in df if col.endswith('x')][5:]

# %%
new_features['r_x_mean'] = df[r_x_columns].mean(axis = 1)
new_features['d_x_mean'] = df[d_x_columns].mean(axis = 1)
new_features['r_x_max'] = df[r_x_columns].max(axis = 1)
new_features['d_x_max'] = df[d_x_columns].max(axis = 1)
new_features['r_x_min'] = df[r_x_columns].min(axis = 1)
new_features['d_x_min'] = df[d_x_columns].min(axis = 1)

# %%
r_y_columns = [col for col in df if col.endswith('y')][:5]
d_y_columns = [col for col in df if col.endswith('y')][5:]

# %%
new_features['r_y_mean'] = df[r_y_columns].mean(axis = 1)
new_features['d_y_mean'] = df[d_y_columns].mean(axis = 1)

# %%
new_features['r_y_max'] = df[r_y_columns].max(axis = 1)
new_features['d_y_max'] = df[d_y_columns].max(axis = 1)
new_features['r_y_min'] = df[r_y_columns].min(axis = 1)
new_features['d_y_min'] = df[d_y_columns].min(axis = 1)

# %%
# coordinates of radiant start point
r_x_min = df[['r1_x', 'r2_x','r3_x','r4_x','r5_x']].min(axis = 1)
r_y_min = df[['r1_y', 'r2_y','r3_y','r4_y','r5_y']].min(axis = 1)

# %%
r_x_max = df[['r1_x', 'r2_x','r3_x','r4_x','r5_x']].max(axis = 1)
r_y_max = df[['r1_y', 'r2_y','r3_y','r4_y','r5_y']].max(axis = 1)

# %%
new_features['r1_dist'] = np.sqrt((df['r1_y'] - r_y_min)**2 + (df['r1_x'] - r_x_min)**2)
new_features['r2_dist'] = np.sqrt((df['r2_y'] - r_y_min)**2 + (df['r2_x'] - r_x_min)**2)
new_features['r3_dist'] = np.sqrt((df['r3_y'] - r_y_min)**2 + (df['r3_x'] - r_x_min)**2)
new_features['r4_dist'] = np.sqrt((df['r4_y'] - r_y_min)**2 + (df['r4_x'] - r_x_min)**2)
new_features['r5_dist'] = np.sqrt((df['r5_y'] - r_y_min)**2 + (df['r5_x'] - r_x_min)**2)

# %%
r_avg_dist = new_features[['r1_dist', 'r2_dist', 'r3_dist', 'r4_dist', 'r5_dist']].mean(axis = 1)

# %%
new_features['d1_dist'] = np.sqrt((df['d1_y'] - r_y_max)**2 + (df['d1_x'] - r_x_max)**2)
new_features['d2_dist'] = np.sqrt((df['d2_y'] - r_y_max)**2 + (df['d2_x'] - r_x_max)**2)
new_features['d3_dist'] = np.sqrt((df['d3_y'] - r_y_max)**2 + (df['d3_x'] - r_x_max)**2)
new_features['d4_dist'] = np.sqrt((df['d4_y'] - r_y_max)**2 + (df['d4_x'] - r_x_max)**2)
new_features['d5_dist'] = np.sqrt((df['d5_y'] - r_y_max)**2 + (df['d5_x'] - r_x_max)**2)

# %%
d_avg_dist = new_features[['d1_dist', 'd2_dist', 'd3_dist', 'd4_dist', 'd5_dist']].mean(axis = 1)

# %%
new_features['dist_prop'] =  d_avg_dist / r_avg_dist

# %%
#r_runes = df[[col for col in df if col.endswith('rune_pickups')][:5]].sum(axis = 1) + 1
#d_runes = df[[col for col in df if col.endswith('rune_pickups')][5:]].sum(axis = 1) + 1
#new_features['runes_prop'] = r_runes / d_runes

# %%
df.shape
# Out:
# (49675, 245)

# %%
#roshan_cols = [col for col in df if col.endswith('roshans_killed')]

# %%
#df = df.drop(roshan_cols, axis = 1, inplace = True)

# %%
df = pd.concat([df, new_features], axis = 1)

# %%
df.shape
# Out:
# (49675, 309)

# %%
df.head()
# Out:
#                                   game_time  game_mode  lobby_type  \
# match_id_hash
# a400b8f29dece5f4d266f49f1ae2e98a        155         22           7
# b9c57c450ce74a2af79c9ce96fac144d        658          4           0
# 6db558535151ea18ca70a6892197db41         21         23           0
# 46a0ddce8f7ed2a8d9bd5edcbb925682        576         22           7
# b1b35ff97723d9b7ade1c9c3cf48f770        453         22           7
#
#                                   objectives_len  chat_len  r1_hero_id  \
# match_id_hash
# a400b8f29dece5f4d266f49f1ae2e98a               1        11          11
# b9c57c450ce74a2af79c9ce96fac144d               3        10          15
# 6db558535151ea18ca70a6892197db41               0         0         101
# 46a0ddce8f7ed2a8d9bd5edcbb925682               1         4          14
# b1b35ff97723d9b7ade1c9c3cf48f770               1         3          42
#
#                                   r1_kills  r1_deaths  r1_assists  r1_denies  \
# match_id_hash
# a400b8f29dece5f4d266f49f1ae2e98a         0          0           0          0
# b9c57c450ce74a2af79c9ce96fac144d         7          2           0          7
# 6db558535151ea18ca70a6892197db41         0          0           0          0
# 46a0ddce8f7ed2a8d9bd5edcbb925682         1          0           3          1
# b1b35ff97723d9b7ade1c9c3cf48f770         0          1           1          0
#
#                                   ...    r2_dist     r3_dist     r4_dist  \
# match_id_hash                     ...
# a400b8f29dece5f4d266f49f1ae2e98a  ...  67.201190   70.000000  100.000000
# b9c57c450ce74a2af79c9ce96fac144d  ...  88.022724  104.995238  104.804580
# 6db558535151ea18ca70a6892197db41  ...  82.219219   66.000000   72.000000
# 46a0ddce8f7ed2a8d9bd5edcbb925682  ...  60.000000   55.605755   58.137767
# b1b35ff97723d9b7ade1c9c3cf48f770  ...  72.000000   50.477718   60.000000
#
#                                      r5_dist    d1_dist    d2_dist    d3_dist  \
# match_id_hash
# a400b8f29dece5f4d266f49f1ae2e98a   51.923020  89.106678  66.121101  72.691127
# b9c57c450ce74a2af79c9ce96fac144d  101.862653  68.117545  68.000000  38.832976
# 6db558535151ea18ca70a6892197db41   64.000000  41.617304  63.529521  38.832976
# 46a0ddce8f7ed2a8d9bd5edcbb925682   94.000000  82.097503  51.419841  98.183502
# b1b35ff97723d9b7ade1c9c3cf48f770   96.187317  90.088845  60.000000  60.959003
#
#                                     d4_dist    d5_dist  dist_prop
# match_id_hash
# a400b8f29dece5f4d266f49f1ae2e98a  80.224684  50.477718   1.031895
# b9c57c450ce74a2af79c9ce96fac144d  40.000000  26.000000   0.602851
# 6db558535151ea18ca70a6892197db41  39.446166  18.973666   0.593917
# 46a0ddce8f7ed2a8d9bd5edcbb925682  54.000000  94.191295   1.067814
# b1b35ff97723d9b7ade1c9c3cf48f770  58.034473  70.114193   0.972764
#
# [5 rows x 309 columns]

# %%
new_features = pd.read_csv('new_features.csv', index_col='match_id_hash')

# %%
df = pd.concat([df, new_features], axis = 1)

# %%
hero_names = pd.read_csv('hero_names.csv', index_col='match_id_hash')

# %%
df = pd.concat([df, hero_names], axis = 1)

# %%
n_fold = 5
folds = StratifiedKFold(n_splits=n_fold, shuffle=True, random_state=42)

# %%
df.shape
# Out:
# (49675, 929)

# %%
df = df.drop('r1_roshans_killed', axis = 1)
df = df.drop('r2_roshans_killed', axis = 1)
df = df.drop('r3_roshans_killed', axis = 1)
df = df.drop('r4_roshans_killed', axis = 1)
df = df.drop('r5_roshans_killed', axis = 1)

# %%
df = df.drop('d1_roshans_killed', axis = 1)
df = df.drop('d2_roshans_killed', axis = 1)
df = df.drop('d3_roshans_killed', axis = 1)
df = df.drop('d4_roshans_killed', axis = 1)
df = df.drop('d5_roshans_killed', axis = 1)

# %%
df.shape
# Out:
# (49675, 919)

# %%
train = df[:split_index].copy()
test = df[split_index:].copy()

# %%
train.head()
# Out:
#                                   game_time  game_mode  lobby_type  \
# match_id_hash
# a400b8f29dece5f4d266f49f1ae2e98a        155         22           7
# b9c57c450ce74a2af79c9ce96fac144d        658          4           0
# 6db558535151ea18ca70a6892197db41         21         23           0
# 46a0ddce8f7ed2a8d9bd5edcbb925682        576         22           7
# b1b35ff97723d9b7ade1c9c3cf48f770        453         22           7
#
#                                   objectives_len  chat_len  r1_hero_id  \
# match_id_hash
# a400b8f29dece5f4d266f49f1ae2e98a               1        11          11
# b9c57c450ce74a2af79c9ce96fac144d               3        10          15
# 6db558535151ea18ca70a6892197db41               0         0         101
# 46a0ddce8f7ed2a8d9bd5edcbb925682               1         4          14
# b1b35ff97723d9b7ade1c9c3cf48f770               1         3          42
#
#                                   r1_kills  r1_deaths  r1_assists  r1_denies  \
# match_id_hash
# a400b8f29dece5f4d266f49f1ae2e98a         0          0           0          0
# b9c57c450ce74a2af79c9ce96fac144d         7          2           0          7
# 6db558535151ea18ca70a6892197db41         0          0           0          0
# 46a0ddce8f7ed2a8d9bd5edcbb925682         1          0           3          1
# b1b35ff97723d9b7ade1c9c3cf48f770         0          1           1          0
#
#                                   ...  d_hero_90  d_hero_91  d_hero_92  \
# match_id_hash                     ...
# a400b8f29dece5f4d266f49f1ae2e98a  ...          0          0          0
# b9c57c450ce74a2af79c9ce96fac144d  ...          0          0          1
# 6db558535151ea18ca70a6892197db41  ...          0          0          0
# 46a0ddce8f7ed2a8d9bd5edcbb925682  ...          0          0          0
# b1b35ff97723d9b7ade1c9c3cf48f770  ...          0          0          0
#
#                                   d_hero_93  d_hero_94  d_hero_95  d_hero_96  \
# match_id_hash
# a400b8f29dece5f4d266f49f1ae2e98a          0          0          0          0
# b9c57c450ce74a2af79c9ce96fac144d          0          0          0          0
# 6db558535151ea18ca70a6892197db41          0          0          0          0
# 46a0ddce8f7ed2a8d9bd5edcbb925682          0          0          0          0
# b1b35ff97723d9b7ade1c9c3cf48f770          0          0          0          0
#
#                                   d_hero_97  d_hero_98  d_hero_99
# match_id_hash
# a400b8f29dece5f4d266f49f1ae2e98a          0          0          0
# b9c57c450ce74a2af79c9ce96fac144d          0          0          0
# 6db558535151ea18ca70a6892197db41          0          0          0
# 46a0ddce8f7ed2a8d9bd5edcbb925682          0          1          0
# b1b35ff97723d9b7ade1c9c3cf48f770          0          0          0
#
# [5 rows x 919 columns]

# %%
train['radiant_win'] = target['radiant_win']

# %%
params = {'boost': 'gbdt',
          'feature_fraction': 0.05,
          'learning_rate': 0.01,
          'max_depth': -1,  
          'metric':'auc',
          'min_data_in_leaf': 50,
          'num_leaves': 32,
          'num_threads': -1,
          'verbosity': 1,
          'objective': 'binary'
         }

X = train.drop(['radiant_win'], axis=1).reset_index(drop=True)
y = target['radiant_win']
X_test = test.reset_index(drop=True)

oof_lgb, prediction_lgb, scores, CV_scores = train_model(X, X_test, y, params=params, folds=folds, model_type='lgb', plot_feature_importance=True, silent = False)
# Out:
# Fold 0 started at Sun Oct 13 08:24:19 2019
# Training until validation scores don't improve for 2000 rounds
# [1000]	training's auc: 0.886887	valid_1's auc: 0.829748
# [2000]	training's auc: 0.93183	valid_1's auc: 0.839329
# [3000]	training's auc: 0.960089	valid_1's auc: 0.842412
# [4000]	training's auc: 0.977965	valid_1's auc: 0.843687
# [5000]	training's auc: 0.988749	valid_1's auc: 0.844117
# [6000]	training's auc: 0.994754	valid_1's auc: 0.844552
# [7000]	training's auc: 0.997805	valid_1's auc: 0.844771
# [8000]	training's auc: 0.999119	valid_1's auc: 0.844551
# Early stopping, best iteration is:
# [6972]	training's auc: 0.997745	valid_1's auc: 0.844786
# Fold 1 started at Sun Oct 13 08:25:02 2019
# Training until validation scores don't improve for 2000 rounds
# [1000]	training's auc: 0.88936	valid_1's auc: 0.819439
# [2000]	training's auc: 0.933908	valid_1's auc: 0.828446
# [3000]	training's auc: 0.961487	valid_1's auc: 0.83133
# [4000]	training's auc: 0.978775	valid_1's auc: 0.833112
# [5000]	training's auc: 0.989167	valid_1's auc: 0.833561
# [6000]	training's auc: 0.994998	valid_1's auc: 0.83367
# [7000]	training's auc: 0.997854	valid_1's auc: 0.833842
# [8000]	training's auc: 0.999139	valid_1's auc: 0.833723
# Early stopping, best iteration is:
# [6682]	training's auc: 0.997149	valid_1's auc: 0.833903
# Fold 2 started at Sun Oct 13 08:25:45 2019
# Training until validation scores don't improve for 2000 rounds
# [1000]	training's auc: 0.886958	valid_1's auc: 0.83468
# [2000]	training's auc: 0.93238	valid_1's auc: 0.842282
# [3000]	training's auc: 0.960444	valid_1's auc: 0.844736
# [4000]	training's auc: 0.97808	valid_1's auc: 0.845671
# [5000]	training's auc: 0.988882	valid_1's auc: 0.84618
# [6000]	training's auc: 0.994886	valid_1's auc: 0.846233
# [7000]	training's auc: 0.99796	valid_1's auc: 0.846403
# [8000]	training's auc: 0.999219	valid_1's auc: 0.846317
# Early stopping, best iteration is:
# [6961]	training's auc: 0.997878	valid_1's auc: 0.846427
# Fold 3 started at Sun Oct 13 08:26:29 2019
# Training until validation scores don't improve for 2000 rounds
# [1000]	training's auc: 0.886808	valid_1's auc: 0.832842
# [2000]	training's auc: 0.93246	valid_1's auc: 0.840538
# [3000]	training's auc: 0.96063	valid_1's auc: 0.842906
# [4000]	training's auc: 0.978373	valid_1's auc: 0.843892
# [5000]	training's auc: 0.988916	valid_1's auc: 0.844388
# [6000]	training's auc: 0.994863	valid_1's auc: 0.844257
# Early stopping, best iteration is:
# [4950]	training's auc: 0.98851	valid_1's auc: 0.844453
# Fold 4 started at Sun Oct 13 08:27:04 2019
# Training until validation scores don't improve for 2000 rounds
# [1000]	training's auc: 0.887044	valid_1's auc: 0.830529
# [2000]	training's auc: 0.93217	valid_1's auc: 0.838338
# [3000]	training's auc: 0.960337	valid_1's auc: 0.840887
# [4000]	training's auc: 0.978038	valid_1's auc: 0.84136
# [5000]	training's auc: 0.988729	valid_1's auc: 0.84145
# [6000]	training's auc: 0.994787	valid_1's auc: 0.841434
# [7000]	training's auc: 0.99784	valid_1's auc: 0.841435
# Early stopping, best iteration is:
# [5235]	training's auc: 0.990539	valid_1's auc: 0.841607
# CV mean score: 0.8422, std: 0.0044.

# %%
prediction_lgb
# Out:
# array([0.24536282, 0.99549788, 0.96996945, ..., 0.53292047, 0.87545979,
#        0.04922726])

# %%
df_submission = pd.DataFrame({'radiant_win_prob': prediction_lgb}, 
                                 index=test.index)
df_submission.to_csv('Submission5_LGB_items_damageInitial_names_parameters.csv')

# %%
prediction_lgb
# Out:
# array([0.24536282, 0.99549788, 0.96996945, ..., 0.53292047, 0.87545979,
#        0.04922726])

# %%
test.head()
# Out:
#                                   game_time  game_mode  lobby_type  \
# match_id_hash
# 30cc2d778dca82f2edb568ce9b585caa         23          4           0
# 70e5ba30f367cea48793b9003fab9d38       1044         22           7
# 4d9ef74d3a2025d79e9423105fd73d41       1091         22           7
# 2bb79e0c1eaac1608e5a09c8e0c6a555        623         22           7
# bec17f099b01d67edc82dfb5ce735a43       1538         22           7
#
#                                   objectives_len  chat_len  r1_hero_id  \
# match_id_hash
# 30cc2d778dca82f2edb568ce9b585caa               0         0          79
# 70e5ba30f367cea48793b9003fab9d38              12         6          23
# 4d9ef74d3a2025d79e9423105fd73d41               6         1          64
# 2bb79e0c1eaac1608e5a09c8e0c6a555               1         0          41
# bec17f099b01d67edc82dfb5ce735a43               7        11          40
#
#                                   r1_kills  r1_deaths  r1_assists  r1_denies  \
# match_id_hash
# 30cc2d778dca82f2edb568ce9b585caa         0          0           0          0
# 70e5ba30f367cea48793b9003fab9d38         3          5           7          1
# 4d9ef74d3a2025d79e9423105fd73d41         3          1           7          1
# 2bb79e0c1eaac1608e5a09c8e0c6a555         0          0           1          2
# bec17f099b01d67edc82dfb5ce735a43         2          7          12          0
#
#                                   ...  d_hero_90  d_hero_91  d_hero_92  \
# match_id_hash                     ...
# 30cc2d778dca82f2edb568ce9b585caa  ...          0          1          0
# 70e5ba30f367cea48793b9003fab9d38  ...          0          0          0
# 4d9ef74d3a2025d79e9423105fd73d41  ...          0          0          0
# 2bb79e0c1eaac1608e5a09c8e0c6a555  ...          0          0          0
# bec17f099b01d67edc82dfb5ce735a43  ...          0          0          0
#
#                                   d_hero_93  d_hero_94  d_hero_95  d_hero_96  \
# match_id_hash
# 30cc2d778dca82f2edb568ce9b585caa          0          0          0          0
# 70e5ba30f367cea48793b9003fab9d38          0          0          1          0
# 4d9ef74d3a2025d79e9423105fd73d41          0          0          0          0
# 2bb79e0c1eaac1608e5a09c8e0c6a555          0          0          0          0
# bec17f099b01d67edc82dfb5ce735a43          0          0          0          0
#
#                                   d_hero_97  d_hero_98  d_hero_99
# match_id_hash
# 30cc2d778dca82f2edb568ce9b585caa          0          0          0
# 70e5ba30f367cea48793b9003fab9d38          0          0          1
# 4d9ef74d3a2025d79e9423105fd73d41          0          0          0
# 2bb79e0c1eaac1608e5a09c8e0c6a555          1          1          0
# bec17f099b01d67edc82dfb5ce735a43          0          0          0
#
# [5 rows x 919 columns]

# %%
plt.hist(prediction_lgb, bins=40);
plt.title('Distribution of predictions');

# %%
np.mean(scores)
# Out:
# importance    41.558215
# fold           3.000000
# dtype: float64

# %%
results = []
for i in range(40,140, 5):
    params = {'boost': 'gbdt',
          'feature_fraction': 0.05,
          'learning_rate': 0.01, 
          'max_depth': 7,
          'metric':'auc',
          'min_data_in_leaf': i,
          'num_leaves': 20,
          'num_threads': -1,
          'verbosity': 1,
          'objective': 'binary'
         }
    oof_lgb, prediction_lgb, scores, CV_scores = train_model(X, X_test, y, params=params, folds=folds, model_type='lgb', plot_feature_importance=False, silent = False)
    results.append({i, CV_scores})
# Out:
# Fold 0 started at Sun Oct 13 17:52:51 2019
# Training until validation scores don't improve for 2000 rounds
# [1000]	training's auc: 0.864135	valid_1's auc: 0.828227
# [2000]	training's auc: 0.898746	valid_1's auc: 0.837739
# [3000]	training's auc: 0.923572	valid_1's auc: 0.841405
# [4000]	training's auc: 0.942571	valid_1's auc: 0.842859
# [5000]	training's auc: 0.957659	valid_1's auc: 0.843742
# [6000]	training's auc: 0.96944	valid_1's auc: 0.844039
# [7000]	training's auc: 0.978425	valid_1's auc: 0.844621
# [8000]	training's auc: 0.985047	valid_1's auc: 0.844621
# [9000]	training's auc: 0.989839	valid_1's auc: 0.844717
# [10000]	training's auc: 0.993313	valid_1's auc: 0.844899
# [11000]	training's auc: 0.995739	valid_1's auc: 0.844689
# [12000]	training's auc: 0.997357	valid_1's auc: 0.844862
# Early stopping, best iteration is:
# [10053]	training's auc: 0.993461	valid_1's auc: 0.844901
# Fold 1 started at Sun Oct 13 17:53:39 2019
# Training until validation scores don't improve for 2000 rounds
# [1000]	training's auc: 0.866701	valid_1's auc: 0.817879
# [2000]	training's auc: 0.901056	valid_1's auc: 0.827282
# [3000]	training's auc: 0.925487	valid_1's auc: 0.831006
# [4000]	training's auc: 0.944205	valid_1's auc: 0.832926
# [5000]	training's auc: 0.958738	valid_1's auc: 0.833844
# [6000]	training's auc: 0.970067	valid_1's auc: 0.834335
# [7000]	training's auc: 0.978616	valid_1's auc: 0.83458
# [8000]	training's auc: 0.985066	valid_1's auc: 0.83451
# [9000]	training's auc: 0.989847	valid_1's auc: 0.834837
# [10000]	training's auc: 0.993283	valid_1's auc: 0.834837
# [11000]	training's auc: 0.995641	valid_1's auc: 0.834901
# [12000]	training's auc: 0.997283	valid_1's auc: 0.834852
# Early stopping, best iteration is:
# [10830]	training's auc: 0.995289	valid_1's auc: 0.834944
# Fold 2 started at Sun Oct 13 17:54:31 2019
# Training until validation scores don't improve for 2000 rounds
# [1000]	training's auc: 0.864063	valid_1's auc: 0.833557
# [2000]	training's auc: 0.899027	valid_1's auc: 0.842121
# [3000]	training's auc: 0.923893	valid_1's auc: 0.84471
# [4000]	training's auc: 0.942733	valid_1's auc: 0.845792
# [5000]	training's auc: 0.957558	valid_1's auc: 0.846195
# [6000]	training's auc: 0.969311	valid_1's auc: 0.846428
# [7000]	training's auc: 0.978403	valid_1's auc: 0.846616
# [8000]	training's auc: 0.985223	valid_1's auc: 0.846526
# [9000]	training's auc: 0.99012	valid_1's auc: 0.846388
# Early stopping, best iteration is:
# [7307]	training's auc: 0.980782	valid_1's auc: 0.846784
# Fold 3 started at Sun Oct 13 17:55:11 2019
# Training until validation scores don't improve for 2000 rounds
# [1000]	training's auc: 0.863808	valid_1's auc: 0.831634
# [2000]	training's auc: 0.898828	valid_1's auc: 0.8401
# [3000]	training's auc: 0.923833	valid_1's auc: 0.84284
# [4000]	training's auc: 0.942737	valid_1's auc: 0.844155
# [5000]	training's auc: 0.957676	valid_1's auc: 0.844711
# [6000]	training's auc: 0.969423	valid_1's auc: 0.844775
# [7000]	training's auc: 0.97831	valid_1's auc: 0.844561
# Early stopping, best iteration is:
# [5667]	training's auc: 0.965861	valid_1's auc: 0.844846
# Fold 4 started at Sun Oct 13 17:55:43 2019
# Training until validation scores don't improve for 2000 rounds
# [1000]	training's auc: 0.864346	valid_1's auc: 0.828652
# [2000]	training's auc: 0.898899	valid_1's auc: 0.837652
# [3000]	training's auc: 0.923681	valid_1's auc: 0.840701
# [4000]	training's auc: 0.942643	valid_1's auc: 0.841463
# [5000]	training's auc: 0.957485	valid_1's auc: 0.842024
# [6000]	training's auc: 0.969073	valid_1's auc: 0.842102
# [7000]	training's auc: 0.978176	valid_1's auc: 0.842192
# [8000]	training's auc: 0.984804	valid_1's auc: 0.842167
# [9000]	training's auc: 0.989762	valid_1's auc: 0.842226
# [10000]	training's auc: 0.993268	valid_1's auc: 0.842309
# [11000]	training's auc: 0.995698	valid_1's auc: 0.842188
# Early stopping, best iteration is:
# [9969]	training's auc: 0.993187	valid_1's auc: 0.84236
# CV mean score: 0.8428, std: 0.0042.
# Fold 0 started at Sun Oct 13 17:56:30 2019
# Training until validation scores don't improve for 2000 rounds
# [1000]	training's auc: 0.863954	valid_1's auc: 0.828251
# [2000]	training's auc: 0.89845	valid_1's auc: 0.837888
# [3000]	training's auc: 0.923156	valid_1's auc: 0.841647
# [4000]	training's auc: 0.942059	valid_1's auc: 0.843177
# [5000]	training's auc: 0.95712	valid_1's auc: 0.844027
# [6000]	training's auc: 0.969001	valid_1's auc: 0.8444
# [7000]	training's auc: 0.977986	valid_1's auc: 0.844771
# [8000]	training's auc: 0.984702	valid_1's auc: 0.845002
# [9000]	training's auc: 0.98957	valid_1's auc: 0.844892
# [10000]	training's auc: 0.99312	valid_1's auc: 0.845029
# [11000]	training's auc: 0.995624	valid_1's auc: 0.844815
# Early stopping, best iteration is:
# [9902]	training's auc: 0.992839	valid_1's auc: 0.845051
# Fold 1 started at Sun Oct 13 17:57:17 2019
# Training until validation scores don't improve for 2000 rounds
# [1000]	training's auc: 0.866541	valid_1's auc: 0.817822
# [2000]	training's auc: 0.900819	valid_1's auc: 0.827106
# [3000]	training's auc: 0.925139	valid_1's auc: 0.830831
# [4000]	training's auc: 0.943815	valid_1's auc: 0.832862
# [5000]	training's auc: 0.958362	valid_1's auc: 0.833728
# [6000]	training's auc: 0.969714	valid_1's auc: 0.834049
# [7000]	training's auc: 0.978334	valid_1's auc: 0.834321
# [8000]	training's auc: 0.984812	valid_1's auc: 0.834418
# [9000]	training's auc: 0.989619	valid_1's auc: 0.834394
# [10000]	training's auc: 0.993092	valid_1's auc: 0.834423
# Early stopping, best iteration is:
# [8346]	training's auc: 0.986651	valid_1's auc: 0.834517
# Fold 2 started at Sun Oct 13 17:58:00 2019
# Training until validation scores don't improve for 2000 rounds
# [1000]	training's auc: 0.863896	valid_1's auc: 0.833586
# [2000]	training's auc: 0.898861	valid_1's auc: 0.841847
# [3000]	training's auc: 0.923582	valid_1's auc: 0.844391
# [4000]	training's auc: 0.942323	valid_1's auc: 0.845683
# [5000]	training's auc: 0.957263	valid_1's auc: 0.846138
# [6000]	training's auc: 0.969073	valid_1's auc: 0.846346
# [7000]	training's auc: 0.97814	valid_1's auc: 0.846386
# [8000]	training's auc: 0.9849	valid_1's auc: 0.846261
# Early stopping, best iteration is:
# [6440]	training's auc: 0.973469	valid_1's auc: 0.846453
# Fold 3 started at Sun Oct 13 17:58:35 2019
# Training until validation scores don't improve for 2000 rounds
# [1000]	training's auc: 0.863665	valid_1's auc: 0.831503
# [2000]	training's auc: 0.898721	valid_1's auc: 0.839899
# [3000]	training's auc: 0.923536	valid_1's auc: 0.842631
# [4000]	training's auc: 0.942397	valid_1's auc: 0.843996
# [5000]	training's auc: 0.957251	valid_1's auc: 0.844524
# [6000]	training's auc: 0.969128	valid_1's auc: 0.844631
# [7000]	training's auc: 0.978011	valid_1's auc: 0.84429
# [8000]	training's auc: 0.984668	valid_1's auc: 0.844308
# Early stopping, best iteration is:
# [6052]	training's auc: 0.96963	valid_1's auc: 0.844686
# Fold 4 started at Sun Oct 13 17:59:08 2019
# Training until validation scores don't improve for 2000 rounds
# [1000]	training's auc: 0.864283	valid_1's auc: 0.828685
# [2000]	training's auc: 0.898739	valid_1's auc: 0.837653
# [3000]	training's auc: 0.923389	valid_1's auc: 0.840757
# [4000]	training's auc: 0.94227	valid_1's auc: 0.841562
# [5000]	training's auc: 0.956967	valid_1's auc: 0.842092
# [6000]	training's auc: 0.968608	valid_1's auc: 0.842277
# [7000]	training's auc: 0.977656	valid_1's auc: 0.842248
# Early stopping, best iteration is:
# [5973]	training's auc: 0.968324	valid_1's auc: 0.84232
# CV mean score: 0.8426, std: 0.0043.
# Fold 0 started at Sun Oct 13 17:59:40 2019
# Training until validation scores don't improve for 2000 rounds
# [1000]	training's auc: 0.863818	valid_1's auc: 0.828296
# [2000]	training's auc: 0.898217	valid_1's auc: 0.837876
# [3000]	training's auc: 0.92275	valid_1's auc: 0.841467
# [4000]	training's auc: 0.941575	valid_1's auc: 0.84315
# [5000]	training's auc: 0.956682	valid_1's auc: 0.84398
# [6000]	training's auc: 0.968443	valid_1's auc: 0.844414
# [7000]	training's auc: 0.977609	valid_1's auc: 0.844561
# [8000]	training's auc: 0.984382	valid_1's auc: 0.844561
# Early stopping, best iteration is:
# [6793]	training's auc: 0.975904	valid_1's auc: 0.844683
# Fold 1 started at Sun Oct 13 18:00:14 2019
# Training until validation scores don't improve for 2000 rounds
# [1000]	training's auc: 0.866422	valid_1's auc: 0.817765
# [2000]	training's auc: 0.900617	valid_1's auc: 0.827322
# [3000]	training's auc: 0.924829	valid_1's auc: 0.831178
# [4000]	training's auc: 0.943382	valid_1's auc: 0.832976
# [5000]	training's auc: 0.958016	valid_1's auc: 0.834056
# [6000]	training's auc: 0.969332	valid_1's auc: 0.834198
# [7000]	training's auc: 0.978028	valid_1's auc: 0.834446
# [8000]	training's auc: 0.984611	valid_1's auc: 0.834684
# [9000]	training's auc: 0.989431	valid_1's auc: 0.834812
# [10000]	training's auc: 0.992901	valid_1's auc: 0.834823
# [11000]	training's auc: 0.995382	valid_1's auc: 0.834856
# [12000]	training's auc: 0.99706	valid_1's auc: 0.834978
# [13000]	training's auc: 0.998177	valid_1's auc: 0.834895
# Early stopping, best iteration is:
# [11993]	training's auc: 0.997053	valid_1's auc: 0.834997
# Fold 2 started at Sun Oct 13 18:01:10 2019
# Training until validation scores don't improve for 2000 rounds
# [1000]	training's auc: 0.863807	valid_1's auc: 0.833514
# [2000]	training's auc: 0.898599	valid_1's auc: 0.841746
# [3000]	training's auc: 0.92331	valid_1's auc: 0.844263
# [4000]	training's auc: 0.941893	valid_1's auc: 0.845513
# [5000]	training's auc: 0.956715	valid_1's auc: 0.846069
# [6000]	training's auc: 0.968578	valid_1's auc: 0.846375
# [7000]	training's auc: 0.977721	valid_1's auc: 0.846616
# [8000]	training's auc: 0.984476	valid_1's auc: 0.846449
# [9000]	training's auc: 0.989494	valid_1's auc: 0.846468
# Early stopping, best iteration is:
# [7026]	training's auc: 0.977916	valid_1's auc: 0.846624
# Fold 3 started at Sun Oct 13 18:01:46 2019
# Training until validation scores don't improve for 2000 rounds
# [1000]	training's auc: 0.863604	valid_1's auc: 0.831694
# [2000]	training's auc: 0.898397	valid_1's auc: 0.840236
# [3000]	training's auc: 0.923186	valid_1's auc: 0.843111
# [4000]	training's auc: 0.942062	valid_1's auc: 0.844469
# [5000]	training's auc: 0.956908	valid_1's auc: 0.844986
# [6000]	training's auc: 0.968773	valid_1's auc: 0.845324
# [7000]	training's auc: 0.977682	valid_1's auc: 0.845368
# [8000]	training's auc: 0.984408	valid_1's auc: 0.845067
# Early stopping, best iteration is:
# [6874]	training's auc: 0.976683	valid_1's auc: 0.845393
# Fold 4 started at Sun Oct 13 18:02:22 2019
# Training until validation scores don't improve for 2000 rounds
# [1000]	training's auc: 0.864162	valid_1's auc: 0.828774
# [2000]	training's auc: 0.89844	valid_1's auc: 0.837746
# [3000]	training's auc: 0.922895	valid_1's auc: 0.840872
# [4000]	training's auc: 0.941736	valid_1's auc: 0.84191
# [5000]	training's auc: 0.956459	valid_1's auc: 0.842142
# [6000]	training's auc: 0.968124	valid_1's auc: 0.84229
# [7000]	training's auc: 0.977268	valid_1's auc: 0.842379
# [8000]	training's auc: 0.984133	valid_1's auc: 0.84225
# Early stopping, best iteration is:
# [6701]	training's auc: 0.974743	valid_1's auc: 0.842435
# CV mean score: 0.8428, std: 0.0041.
# Fold 0 started at Sun Oct 13 18:02:56 2019
# Training until validation scores don't improve for 2000 rounds
# [1000]	training's auc: 0.863739	valid_1's auc: 0.828401
# [2000]	training's auc: 0.897971	valid_1's auc: 0.838077
# [3000]	training's auc: 0.922459	valid_1's auc: 0.841788
# [4000]	training's auc: 0.941187	valid_1's auc: 0.84358
# [5000]	training's auc: 0.956231	valid_1's auc: 0.844447
# [6000]	training's auc: 0.967989	valid_1's auc: 0.844894
# [7000]	training's auc: 0.977106	valid_1's auc: 0.845039
# [8000]	training's auc: 0.983901	valid_1's auc: 0.845149
# [9000]	training's auc: 0.988917	valid_1's auc: 0.845123
# [10000]	training's auc: 0.992548	valid_1's auc: 0.844856
# Early stopping, best iteration is:
# [8923]	training's auc: 0.988585	valid_1's auc: 0.845192
# Fold 1 started at Sun Oct 13 18:03:39 2019
# Training until validation scores don't improve for 2000 rounds
# [1000]	training's auc: 0.866282	valid_1's auc: 0.817832
# [2000]	training's auc: 0.900426	valid_1's auc: 0.827242
# [3000]	training's auc: 0.924542	valid_1's auc: 0.830848
# [4000]	training's auc: 0.943043	valid_1's auc: 0.8329
# [5000]	training's auc: 0.957494	valid_1's auc: 0.833806
# [6000]	training's auc: 0.968822	valid_1's auc: 0.834155
# [7000]	training's auc: 0.977497	valid_1's auc: 0.834271
# [8000]	training's auc: 0.984151	valid_1's auc: 0.834178
# [9000]	training's auc: 0.989015	valid_1's auc: 0.834331
# [10000]	training's auc: 0.992604	valid_1's auc: 0.834389
# [11000]	training's auc: 0.995124	valid_1's auc: 0.83441
# [12000]	training's auc: 0.996872	valid_1's auc: 0.834378
# Early stopping, best iteration is:
# [10578]	training's auc: 0.994179	valid_1's auc: 0.834549
# Fold 2 started at Sun Oct 13 18:04:29 2019
# Training until validation scores don't improve for 2000 rounds
# [1000]	training's auc: 0.863671	valid_1's auc: 0.833548
# [2000]	training's auc: 0.898402	valid_1's auc: 0.841863
# [3000]	training's auc: 0.922818	valid_1's auc: 0.844387
# [4000]	training's auc: 0.941388	valid_1's auc: 0.845708
# [5000]	training's auc: 0.956136	valid_1's auc: 0.84629
# [6000]	training's auc: 0.968083	valid_1's auc: 0.846507
# [7000]	training's auc: 0.977145	valid_1's auc: 0.846211
# Early stopping, best iteration is:
# [5886]	training's auc: 0.966918	valid_1's auc: 0.846567
# Fold 3 started at Sun Oct 13 18:05:01 2019
# Training until validation scores don't improve for 2000 rounds
# [1000]	training's auc: 0.863428	valid_1's auc: 0.831726
# [2000]	training's auc: 0.898106	valid_1's auc: 0.840283
# [3000]	training's auc: 0.922851	valid_1's auc: 0.843102
# [4000]	training's auc: 0.941593	valid_1's auc: 0.844299
# [5000]	training's auc: 0.956404	valid_1's auc: 0.844845
# [6000]	training's auc: 0.968213	valid_1's auc: 0.845073
# [7000]	training's auc: 0.977206	valid_1's auc: 0.844901
# [8000]	training's auc: 0.983948	valid_1's auc: 0.844593
# Early stopping, best iteration is:
# [6072]	training's auc: 0.96891	valid_1's auc: 0.845161
# Fold 4 started at Sun Oct 13 18:05:34 2019
# Training until validation scores don't improve for 2000 rounds
# [1000]	training's auc: 0.864022	valid_1's auc: 0.828821
# [2000]	training's auc: 0.898189	valid_1's auc: 0.837892
# [3000]	training's auc: 0.922615	valid_1's auc: 0.840851
# [4000]	training's auc: 0.941263	valid_1's auc: 0.841735
# [5000]	training's auc: 0.955953	valid_1's auc: 0.842207
# [6000]	training's auc: 0.9676	valid_1's auc: 0.84224
# [7000]	training's auc: 0.976701	valid_1's auc: 0.842089
# [8000]	training's auc: 0.983545	valid_1's auc: 0.841705
# Early stopping, best iteration is:
# [6052]	training's auc: 0.968091	valid_1's auc: 0.842294
# CV mean score: 0.8428, std: 0.0043.
# Fold 0 started at Sun Oct 13 18:06:06 2019
# Training until validation scores don't improve for 2000 rounds
# [1000]	training's auc: 0.863625	valid_1's auc: 0.828321
# [2000]	training's auc: 0.897745	valid_1's auc: 0.83791
# [3000]	training's auc: 0.922179	valid_1's auc: 0.841765
# [4000]	training's auc: 0.94088	valid_1's auc: 0.843222
# [5000]	training's auc: 0.955885	valid_1's auc: 0.844056
# [6000]	training's auc: 0.967674	valid_1's auc: 0.844523
# [7000]	training's auc: 0.976817	valid_1's auc: 0.844741
# [8000]	training's auc: 0.983692	valid_1's auc: 0.844833
# [9000]	training's auc: 0.988775	valid_1's auc: 0.844758
# [10000]	training's auc: 0.992503	valid_1's auc: 0.844839
# Early stopping, best iteration is:
# [8344]	training's auc: 0.985606	valid_1's auc: 0.84497
# Fold 1 started at Sun Oct 13 18:06:49 2019
# Training until validation scores don't improve for 2000 rounds
# [1000]	training's auc: 0.866183	valid_1's auc: 0.817849
# [2000]	training's auc: 0.900185	valid_1's auc: 0.827314
# [3000]	training's auc: 0.924256	valid_1's auc: 0.830871
# [4000]	training's auc: 0.942702	valid_1's auc: 0.83287
# [5000]	training's auc: 0.957205	valid_1's auc: 0.83372
# [6000]	training's auc: 0.968447	valid_1's auc: 0.834017
# [7000]	training's auc: 0.977173	valid_1's auc: 0.834021
# [8000]	training's auc: 0.983764	valid_1's auc: 0.833902
# Early stopping, best iteration is:
# [6228]	training's auc: 0.970667	valid_1's auc: 0.834163
# Fold 2 started at Sun Oct 13 18:07:24 2019
# Training until validation scores don't improve for 2000 rounds
# [1000]	training's auc: 0.86353	valid_1's auc: 0.833492
# [2000]	training's auc: 0.898163	valid_1's auc: 0.841758
# [3000]	training's auc: 0.922461	valid_1's auc: 0.844284
# [4000]	training's auc: 0.941058	valid_1's auc: 0.845751
# [5000]	training's auc: 0.955812	valid_1's auc: 0.846388
# [6000]	training's auc: 0.967685	valid_1's auc: 0.846537
# [7000]	training's auc: 0.976891	valid_1's auc: 0.846527
# [8000]	training's auc: 0.983767	valid_1's auc: 0.846338
# Early stopping, best iteration is:
# [6895]	training's auc: 0.976002	valid_1's auc: 0.846608
# Fold 3 started at Sun Oct 13 18:07:59 2019
# Training until validation scores don't improve for 2000 rounds
# [1000]	training's auc: 0.863332	valid_1's auc: 0.831793
# [2000]	training's auc: 0.897945	valid_1's auc: 0.840109
# [3000]	training's auc: 0.922532	valid_1's auc: 0.843032
# [4000]	training's auc: 0.941208	valid_1's auc: 0.844301
# [5000]	training's auc: 0.955995	valid_1's auc: 0.844742
# [6000]	training's auc: 0.967833	valid_1's auc: 0.844813
# [7000]	training's auc: 0.976807	valid_1's auc: 0.844603
# Early stopping, best iteration is:
# [5670]	training's auc: 0.96422	valid_1's auc: 0.844931
# Fold 4 started at Sun Oct 13 18:08:30 2019
# Training until validation scores don't improve for 2000 rounds
# [1000]	training's auc: 0.863904	valid_1's auc: 0.828762
# [2000]	training's auc: 0.897985	valid_1's auc: 0.837991
# [3000]	training's auc: 0.922352	valid_1's auc: 0.841191
# [4000]	training's auc: 0.940882	valid_1's auc: 0.841979
# [5000]	training's auc: 0.955562	valid_1's auc: 0.842296
# [6000]	training's auc: 0.967274	valid_1's auc: 0.842327
# [7000]	training's auc: 0.976439	valid_1's auc: 0.842147
# [8000]	training's auc: 0.983269	valid_1's auc: 0.842059
# Early stopping, best iteration is:
# [6070]	training's auc: 0.967993	valid_1's auc: 0.842378
# CV mean score: 0.8426, std: 0.0044.
# Fold 0 started at Sun Oct 13 18:09:03 2019
# Training until validation scores don't improve for 2000 rounds
# [1000]	training's auc: 0.863514	valid_1's auc: 0.828366
# [2000]	training's auc: 0.897543	valid_1's auc: 0.838004
# [3000]	training's auc: 0.921863	valid_1's auc: 0.841789
# [4000]	training's auc: 0.940476	valid_1's auc: 0.843072
# [5000]	training's auc: 0.955365	valid_1's auc: 0.843925
# [6000]	training's auc: 0.967232	valid_1's auc: 0.844501
# [7000]	training's auc: 0.976383	valid_1's auc: 0.844559
# [8000]	training's auc: 0.983318	valid_1's auc: 0.844645
# Early stopping, best iteration is:
# [6832]	training's auc: 0.975024	valid_1's auc: 0.844712
# Fold 1 started at Sun Oct 13 18:09:38 2019
# Training until validation scores don't improve for 2000 rounds
# [1000]	training's auc: 0.866078	valid_1's auc: 0.817811
# [2000]	training's auc: 0.899964	valid_1's auc: 0.827389
# [3000]	training's auc: 0.923927	valid_1's auc: 0.831046
# [4000]	training's auc: 0.942225	valid_1's auc: 0.832866
# [5000]	training's auc: 0.956795	valid_1's auc: 0.833805
# [6000]	training's auc: 0.967956	valid_1's auc: 0.834207
# [7000]	training's auc: 0.976812	valid_1's auc: 0.83407
# [8000]	training's auc: 0.983498	valid_1's auc: 0.83422
# [9000]	training's auc: 0.988503	valid_1's auc: 0.834255
# Early stopping, best iteration is:
# [7662]	training's auc: 0.981418	valid_1's auc: 0.834313
# Fold 2 started at Sun Oct 13 18:10:17 2019
# Training until validation scores don't improve for 2000 rounds
# [1000]	training's auc: 0.863384	valid_1's auc: 0.833515
# [2000]	training's auc: 0.897956	valid_1's auc: 0.841779
# [3000]	training's auc: 0.922267	valid_1's auc: 0.84433
# [4000]	training's auc: 0.940779	valid_1's auc: 0.845719
# [5000]	training's auc: 0.955529	valid_1's auc: 0.846165
# [6000]	training's auc: 0.967492	valid_1's auc: 0.846246
# [7000]	training's auc: 0.976671	valid_1's auc: 0.846577
# [8000]	training's auc: 0.98359	valid_1's auc: 0.846365
# [9000]	training's auc: 0.988757	valid_1's auc: 0.846404
# Early stopping, best iteration is:
# [7370]	training's auc: 0.979409	valid_1's auc: 0.846654
# Fold 3 started at Sun Oct 13 18:10:54 2019
# Training until validation scores don't improve for 2000 rounds
# [1000]	training's auc: 0.863236	valid_1's auc: 0.831644
# [2000]	training's auc: 0.897745	valid_1's auc: 0.840237
# [3000]	training's auc: 0.922237	valid_1's auc: 0.843081
# [4000]	training's auc: 0.940905	valid_1's auc: 0.844267
# [5000]	training's auc: 0.955602	valid_1's auc: 0.844739
# [6000]	training's auc: 0.967339	valid_1's auc: 0.844987
# [7000]	training's auc: 0.976331	valid_1's auc: 0.844953
# [8000]	training's auc: 0.983157	valid_1's auc: 0.844891
# Early stopping, best iteration is:
# [6630]	training's auc: 0.973242	valid_1's auc: 0.845141
# Fold 4 started at Sun Oct 13 18:11:29 2019
# Training until validation scores don't improve for 2000 rounds
# [1000]	training's auc: 0.863725	valid_1's auc: 0.828757
# [2000]	training's auc: 0.89777	valid_1's auc: 0.837935
# [3000]	training's auc: 0.922096	valid_1's auc: 0.841028
# [4000]	training's auc: 0.940617	valid_1's auc: 0.841916
# [5000]	training's auc: 0.955194	valid_1's auc: 0.842279
# [6000]	training's auc: 0.966774	valid_1's auc: 0.842687
# [7000]	training's auc: 0.975904	valid_1's auc: 0.842521
# [8000]	training's auc: 0.982809	valid_1's auc: 0.842471
# Early stopping, best iteration is:
# [6028]	training's auc: 0.967026	valid_1's auc: 0.842718
# CV mean score: 0.8427, std: 0.0044.
# Fold 0 started at Sun Oct 13 18:12:02 2019
# Training until validation scores don't improve for 2000 rounds
# [1000]	training's auc: 0.863394	valid_1's auc: 0.828445
# [2000]	training's auc: 0.897385	valid_1's auc: 0.838045
# [3000]	training's auc: 0.921596	valid_1's auc: 0.841802
# [4000]	training's auc: 0.940201	valid_1's auc: 0.843346
# [5000]	training's auc: 0.954967	valid_1's auc: 0.844007
# [6000]	training's auc: 0.966743	valid_1's auc: 0.844615
# [7000]	training's auc: 0.975914	valid_1's auc: 0.844726
# [8000]	training's auc: 0.982851	valid_1's auc: 0.844588
# Early stopping, best iteration is:
# [6793]	training's auc: 0.974193	valid_1's auc: 0.844826
# Fold 1 started at Sun Oct 13 18:12:37 2019
# Training until validation scores don't improve for 2000 rounds
# [1000]	training's auc: 0.865991	valid_1's auc: 0.817676
# [2000]	training's auc: 0.899769	valid_1's auc: 0.827249
# [3000]	training's auc: 0.923682	valid_1's auc: 0.831027
# [4000]	training's auc: 0.941904	valid_1's auc: 0.832969
# [5000]	training's auc: 0.956244	valid_1's auc: 0.833861
# [6000]	training's auc: 0.967573	valid_1's auc: 0.834278
# [7000]	training's auc: 0.976365	valid_1's auc: 0.83448
# [8000]	training's auc: 0.983116	valid_1's auc: 0.834391
# Early stopping, best iteration is:
# [6991]	training's auc: 0.97629	valid_1's auc: 0.834505
# Fold 2 started at Sun Oct 13 18:13:14 2019
# Training until validation scores don't improve for 2000 rounds
# [1000]	training's auc: 0.863351	valid_1's auc: 0.833512
# [2000]	training's auc: 0.897705	valid_1's auc: 0.841773
# [3000]	training's auc: 0.921927	valid_1's auc: 0.844383
# [4000]	training's auc: 0.940312	valid_1's auc: 0.845731
# [5000]	training's auc: 0.955073	valid_1's auc: 0.846079
# [6000]	training's auc: 0.967049	valid_1's auc: 0.846422
# [7000]	training's auc: 0.976208	valid_1's auc: 0.846611
# [8000]	training's auc: 0.983275	valid_1's auc: 0.846391
# Early stopping, best iteration is:
# [6957]	training's auc: 0.975865	valid_1's auc: 0.84665
# Fold 3 started at Sun Oct 13 18:13:50 2019
# Training until validation scores don't improve for 2000 rounds
# [1000]	training's auc: 0.863131	valid_1's auc: 0.83181
# [2000]	training's auc: 0.897413	valid_1's auc: 0.840426
# [3000]	training's auc: 0.921919	valid_1's auc: 0.843357
# [4000]	training's auc: 0.940498	valid_1's auc: 0.844601
# [5000]	training's auc: 0.955287	valid_1's auc: 0.845105
# [6000]	training's auc: 0.967096	valid_1's auc: 0.8452
# [7000]	training's auc: 0.976066	valid_1's auc: 0.845198
# Early stopping, best iteration is:
# [5637]	training's auc: 0.963224	valid_1's auc: 0.845416
# Fold 4 started at Sun Oct 13 18:14:22 2019
# Training until validation scores don't improve for 2000 rounds
# [1000]	training's auc: 0.863702	valid_1's auc: 0.828777
# [2000]	training's auc: 0.897609	valid_1's auc: 0.837853
# [3000]	training's auc: 0.921762	valid_1's auc: 0.840975
# [4000]	training's auc: 0.940289	valid_1's auc: 0.842075
# [5000]	training's auc: 0.954874	valid_1's auc: 0.842634
# [6000]	training's auc: 0.966429	valid_1's auc: 0.842718
# [7000]	training's auc: 0.975679	valid_1's auc: 0.842676
# Early stopping, best iteration is:
# [5719]	training's auc: 0.963487	valid_1's auc: 0.842791
# CV mean score: 0.8428, std: 0.0043.
# Fold 0 started at Sun Oct 13 18:14:54 2019
# Training until validation scores don't improve for 2000 rounds
# [1000]	training's auc: 0.863285	valid_1's auc: 0.828348
# [2000]	training's auc: 0.897112	valid_1's auc: 0.838068
# [3000]	training's auc: 0.921218	valid_1's auc: 0.841777
# [4000]	training's auc: 0.939778	valid_1's auc: 0.843425
# [5000]	training's auc: 0.954521	valid_1's auc: 0.844279
# [6000]	training's auc: 0.966373	valid_1's auc: 0.844687
# [7000]	training's auc: 0.975553	valid_1's auc: 0.844916
# [8000]	training's auc: 0.98261	valid_1's auc: 0.844905
# [9000]	training's auc: 0.98786	valid_1's auc: 0.845051
# [10000]	training's auc: 0.991776	valid_1's auc: 0.845153
# [11000]	training's auc: 0.994586	valid_1's auc: 0.845033
# [12000]	training's auc: 0.996518	valid_1's auc: 0.844928
# Early stopping, best iteration is:
# [10281]	training's auc: 0.992665	valid_1's auc: 0.845235
# Fold 1 started at Sun Oct 13 18:15:42 2019
# Training until validation scores don't improve for 2000 rounds
# [1000]	training's auc: 0.865886	valid_1's auc: 0.817863
# [2000]	training's auc: 0.899507	valid_1's auc: 0.827436
# [3000]	training's auc: 0.923266	valid_1's auc: 0.831064
# [4000]	training's auc: 0.941439	valid_1's auc: 0.833011
# [5000]	training's auc: 0.955938	valid_1's auc: 0.833883
# [6000]	training's auc: 0.967161	valid_1's auc: 0.834182
# [7000]	training's auc: 0.976048	valid_1's auc: 0.834323
# [8000]	training's auc: 0.982807	valid_1's auc: 0.834441
# [9000]	training's auc: 0.987999	valid_1's auc: 0.834524
# [10000]	training's auc: 0.991716	valid_1's auc: 0.834435
# [11000]	training's auc: 0.994501	valid_1's auc: 0.834268
# Early stopping, best iteration is:
# [9378]	training's auc: 0.989558	valid_1's auc: 0.834563
# Fold 2 started at Sun Oct 13 18:16:29 2019
# Training until validation scores don't improve for 2000 rounds
# [1000]	training's auc: 0.863208	valid_1's auc: 0.833539
# [2000]	training's auc: 0.897522	valid_1's auc: 0.841914
# [3000]	training's auc: 0.921839	valid_1's auc: 0.84452
# [4000]	training's auc: 0.940175	valid_1's auc: 0.845867
# [5000]	training's auc: 0.954879	valid_1's auc: 0.84622
# [6000]	training's auc: 0.966798	valid_1's auc: 0.846543
# [7000]	training's auc: 0.975967	valid_1's auc: 0.846364
# [8000]	training's auc: 0.983004	valid_1's auc: 0.846264
# Early stopping, best iteration is:
# [6430]	training's auc: 0.971083	valid_1's auc: 0.84666
# Fold 3 started at Sun Oct 13 18:17:04 2019
# Training until validation scores don't improve for 2000 rounds
# [1000]	training's auc: 0.862962	valid_1's auc: 0.831729
# [2000]	training's auc: 0.897211	valid_1's auc: 0.840202
# [3000]	training's auc: 0.921533	valid_1's auc: 0.843166
# [4000]	training's auc: 0.940012	valid_1's auc: 0.844369
# [5000]	training's auc: 0.954737	valid_1's auc: 0.844729
# [6000]	training's auc: 0.966563	valid_1's auc: 0.844844
# [7000]	training's auc: 0.975629	valid_1's auc: 0.84462
# Early stopping, best iteration is:
# [5662]	training's auc: 0.962918	valid_1's auc: 0.844939
# Fold 4 started at Sun Oct 13 18:17:36 2019
# Training until validation scores don't improve for 2000 rounds
# [1000]	training's auc: 0.863606	valid_1's auc: 0.828777
# [2000]	training's auc: 0.897386	valid_1's auc: 0.83792
# [3000]	training's auc: 0.921415	valid_1's auc: 0.841188
# [4000]	training's auc: 0.939702	valid_1's auc: 0.842234
# [5000]	training's auc: 0.954234	valid_1's auc: 0.842517
# [6000]	training's auc: 0.966002	valid_1's auc: 0.842722
# [7000]	training's auc: 0.975244	valid_1's auc: 0.842656
# [8000]	training's auc: 0.982225	valid_1's auc: 0.842424
# Early stopping, best iteration is:
# [6763]	training's auc: 0.973269	valid_1's auc: 0.842773
# CV mean score: 0.8428, std: 0.0043.
# Fold 0 started at Sun Oct 13 18:18:15 2019
# Training until validation scores don't improve for 2000 rounds
# [1000]	training's auc: 0.863185	valid_1's auc: 0.828452
# [2000]	training's auc: 0.896924	valid_1's auc: 0.838178
# [3000]	training's auc: 0.920858	valid_1's auc: 0.841868
# [4000]	training's auc: 0.939406	valid_1's auc: 0.84336
# [5000]	training's auc: 0.95425	valid_1's auc: 0.844251
# [6000]	training's auc: 0.965998	valid_1's auc: 0.844677
# [7000]	training's auc: 0.975109	valid_1's auc: 0.844833
# [8000]	training's auc: 0.982324	valid_1's auc: 0.845003
# [9000]	training's auc: 0.987619	valid_1's auc: 0.84505
# [10000]	training's auc: 0.99158	valid_1's auc: 0.845073
# [11000]	training's auc: 0.994456	valid_1's auc: 0.844884
# Early stopping, best iteration is:
# [9914]	training's auc: 0.99129	valid_1's auc: 0.845111
# Fold 1 started at Sun Oct 13 18:19:03 2019
# Training until validation scores don't improve for 2000 rounds
# [1000]	training's auc: 0.86576	valid_1's auc: 0.817871
# [2000]	training's auc: 0.899344	valid_1's auc: 0.827318
# [3000]	training's auc: 0.923007	valid_1's auc: 0.831106
# [4000]	training's auc: 0.941195	valid_1's auc: 0.833059
# [5000]	training's auc: 0.955501	valid_1's auc: 0.834057
# [6000]	training's auc: 0.966725	valid_1's auc: 0.834246
# [7000]	training's auc: 0.975679	valid_1's auc: 0.834249
# [8000]	training's auc: 0.982563	valid_1's auc: 0.83425
# Early stopping, best iteration is:
# [6618]	training's auc: 0.972528	valid_1's auc: 0.834325
# Fold 2 started at Sun Oct 13 18:19:39 2019
# Training until validation scores don't improve for 2000 rounds
# [1000]	training's auc: 0.863104	valid_1's auc: 0.833564
# [2000]	training's auc: 0.897338	valid_1's auc: 0.841868
# [3000]	training's auc: 0.921412	valid_1's auc: 0.844589
# [4000]	training's auc: 0.939721	valid_1's auc: 0.846032
# [5000]	training's auc: 0.954373	valid_1's auc: 0.846266
# [6000]	training's auc: 0.966217	valid_1's auc: 0.846281
# [7000]	training's auc: 0.975471	valid_1's auc: 0.846193
# Early stopping, best iteration is:
# [5748]	training's auc: 0.963612	valid_1's auc: 0.846469
# Fold 3 started at Sun Oct 13 18:20:12 2019
# Training until validation scores don't improve for 2000 rounds
# [1000]	training's auc: 0.862889	valid_1's auc: 0.831749
# [2000]	training's auc: 0.897006	valid_1's auc: 0.840254
# [3000]	training's auc: 0.921216	valid_1's auc: 0.843402
# [4000]	training's auc: 0.939557	valid_1's auc: 0.844552
# [5000]	training's auc: 0.954212	valid_1's auc: 0.844884
# [6000]	training's auc: 0.965982	valid_1's auc: 0.844978
# [7000]	training's auc: 0.975123	valid_1's auc: 0.844896
# Early stopping, best iteration is:
# [5667]	training's auc: 0.962366	valid_1's auc: 0.845045
# Fold 4 started at Sun Oct 13 18:20:44 2019
# Training until validation scores don't improve for 2000 rounds
# [1000]	training's auc: 0.863442	valid_1's auc: 0.82877
# [2000]	training's auc: 0.897206	valid_1's auc: 0.837891
# [3000]	training's auc: 0.921174	valid_1's auc: 0.841124
# [4000]	training's auc: 0.939524	valid_1's auc: 0.84217
# [5000]	training's auc: 0.954094	valid_1's auc: 0.84271
# [6000]	training's auc: 0.965763	valid_1's auc: 0.842743
# [7000]	training's auc: 0.975067	valid_1's auc: 0.842669
# Early stopping, best iteration is:
# [5311]	training's auc: 0.957987	valid_1's auc: 0.842874
# CV mean score: 0.8428, std: 0.0044.
# Fold 0 started at Sun Oct 13 18:21:15 2019
# Training until validation scores don't improve for 2000 rounds
# [1000]	training's auc: 0.863124	valid_1's auc: 0.828464
# [2000]	training's auc: 0.896763	valid_1's auc: 0.838229
# [3000]	training's auc: 0.920551	valid_1's auc: 0.842158
# [4000]	training's auc: 0.939017	valid_1's auc: 0.843865
# [5000]	training's auc: 0.953734	valid_1's auc: 0.84468
# [6000]	training's auc: 0.965505	valid_1's auc: 0.845107
# [7000]	training's auc: 0.974781	valid_1's auc: 0.845148
# [8000]	training's auc: 0.98191	valid_1's auc: 0.845104
# Early stopping, best iteration is:
# [6833]	training's auc: 0.973416	valid_1's auc: 0.845212
# Fold 1 started at Sun Oct 13 18:21:51 2019
# Training until validation scores don't improve for 2000 rounds
# [1000]	training's auc: 0.865605	valid_1's auc: 0.81777
# [2000]	training's auc: 0.899119	valid_1's auc: 0.827476
# [3000]	training's auc: 0.922717	valid_1's auc: 0.83121
# [4000]	training's auc: 0.940745	valid_1's auc: 0.833157
# [5000]	training's auc: 0.955008	valid_1's auc: 0.833859
# [6000]	training's auc: 0.966416	valid_1's auc: 0.834051
# [7000]	training's auc: 0.97518	valid_1's auc: 0.834017
# [8000]	training's auc: 0.982003	valid_1's auc: 0.834142
# [9000]	training's auc: 0.987312	valid_1's auc: 0.834308
# [10000]	training's auc: 0.991205	valid_1's auc: 0.834294
# [11000]	training's auc: 0.994146	valid_1's auc: 0.834131
# Early stopping, best iteration is:
# [9867]	training's auc: 0.99074	valid_1's auc: 0.834381
# Fold 2 started at Sun Oct 13 18:22:40 2019
# Training until validation scores don't improve for 2000 rounds
# [1000]	training's auc: 0.862992	valid_1's auc: 0.833681
# [2000]	training's auc: 0.897117	valid_1's auc: 0.84204
# [3000]	training's auc: 0.92113	valid_1's auc: 0.844633
# [4000]	training's auc: 0.939317	valid_1's auc: 0.845926
# [5000]	training's auc: 0.95391	valid_1's auc: 0.846348
# [6000]	training's auc: 0.965818	valid_1's auc: 0.846519
# [7000]	training's auc: 0.975143	valid_1's auc: 0.846394
# Early stopping, best iteration is:
# [5490]	training's auc: 0.960109	valid_1's auc: 0.8467
# Fold 3 started at Sun Oct 13 18:23:11 2019
# Training until validation scores don't improve for 2000 rounds
# [1000]	training's auc: 0.862808	valid_1's auc: 0.831915
# [2000]	training's auc: 0.896734	valid_1's auc: 0.840477
# [3000]	training's auc: 0.920918	valid_1's auc: 0.843549
# [4000]	training's auc: 0.939281	valid_1's auc: 0.844732
# [5000]	training's auc: 0.953989	valid_1's auc: 0.84499
# [6000]	training's auc: 0.965668	valid_1's auc: 0.845119
# [7000]	training's auc: 0.974854	valid_1's auc: 0.845155
# [8000]	training's auc: 0.981938	valid_1's auc: 0.844954
# Early stopping, best iteration is:
# [6392]	training's auc: 0.969548	valid_1's auc: 0.845291
# Fold 4 started at Sun Oct 13 18:23:47 2019
# Training until validation scores don't improve for 2000 rounds
# [1000]	training's auc: 0.863313	valid_1's auc: 0.828764
# [2000]	training's auc: 0.896927	valid_1's auc: 0.8378
# [3000]	training's auc: 0.920803	valid_1's auc: 0.841248
# [4000]	training's auc: 0.939074	valid_1's auc: 0.842177
# [5000]	training's auc: 0.953586	valid_1's auc: 0.842687
# [6000]	training's auc: 0.965216	valid_1's auc: 0.842836
# [7000]	training's auc: 0.974518	valid_1's auc: 0.842734
# [8000]	training's auc: 0.981595	valid_1's auc: 0.842677
# Early stopping, best iteration is:
# [6699]	training's auc: 0.971978	valid_1's auc: 0.842921
# CV mean score: 0.8429, std: 0.0044.
# Fold 0 started at Sun Oct 13 18:24:23 2019
# Training until validation scores don't improve for 2000 rounds
# [1000]	training's auc: 0.862971	valid_1's auc: 0.828324
# [2000]	training's auc: 0.896554	valid_1's auc: 0.838075
# [3000]	training's auc: 0.920357	valid_1's auc: 0.841925
# [4000]	training's auc: 0.938736	valid_1's auc: 0.843727
# [5000]	training's auc: 0.953424	valid_1's auc: 0.844337
# [6000]	training's auc: 0.965137	valid_1's auc: 0.8447
# [7000]	training's auc: 0.974436	valid_1's auc: 0.845032
# [8000]	training's auc: 0.981604	valid_1's auc: 0.845202
# [9000]	training's auc: 0.987029	valid_1's auc: 0.845291
# [10000]	training's auc: 0.991168	valid_1's auc: 0.845174
# Early stopping, best iteration is:
# [8262]	training's auc: 0.983168	valid_1's auc: 0.845367
# Fold 1 started at Sun Oct 13 18:25:04 2019
# Training until validation scores don't improve for 2000 rounds
# [1000]	training's auc: 0.865508	valid_1's auc: 0.817704
# [2000]	training's auc: 0.898897	valid_1's auc: 0.827321
# [3000]	training's auc: 0.922481	valid_1's auc: 0.831295
# [4000]	training's auc: 0.940485	valid_1's auc: 0.833262
# [5000]	training's auc: 0.954671	valid_1's auc: 0.834045
# [6000]	training's auc: 0.966001	valid_1's auc: 0.834036
# [7000]	training's auc: 0.974825	valid_1's auc: 0.834
# [8000]	training's auc: 0.981695	valid_1's auc: 0.83417
# [9000]	training's auc: 0.986929	valid_1's auc: 0.834196
# [10000]	training's auc: 0.990923	valid_1's auc: 0.834203
# Early stopping, best iteration is:
# [8167]	training's auc: 0.982662	valid_1's auc: 0.834295
# Fold 2 started at Sun Oct 13 18:25:45 2019
# Training until validation scores don't improve for 2000 rounds
# [1000]	training's auc: 0.86291	valid_1's auc: 0.833624
# [2000]	training's auc: 0.896912	valid_1's auc: 0.841796
# [3000]	training's auc: 0.920922	valid_1's auc: 0.844239
# [4000]	training's auc: 0.93918	valid_1's auc: 0.84561
# [5000]	training's auc: 0.953693	valid_1's auc: 0.84612
# [6000]	training's auc: 0.965541	valid_1's auc: 0.84626
# [7000]	training's auc: 0.974769	valid_1's auc: 0.846346
# [8000]	training's auc: 0.981872	valid_1's auc: 0.846218
# Early stopping, best iteration is:
# [6889]	training's auc: 0.973863	valid_1's auc: 0.846461
# Fold 3 started at Sun Oct 13 18:26:22 2019
# Training until validation scores don't improve for 2000 rounds
# [1000]	training's auc: 0.862694	valid_1's auc: 0.831795
# [2000]	training's auc: 0.896584	valid_1's auc: 0.840392
# [3000]	training's auc: 0.920612	valid_1's auc: 0.84329
# [4000]	training's auc: 0.938962	valid_1's auc: 0.844452
# [5000]	training's auc: 0.953677	valid_1's auc: 0.844736
# [6000]	training's auc: 0.965464	valid_1's auc: 0.844736
# [7000]	training's auc: 0.97464	valid_1's auc: 0.844713
# [8000]	training's auc: 0.981693	valid_1's auc: 0.844503
# Early stopping, best iteration is:
# [6044]	training's auc: 0.965869	valid_1's auc: 0.844797
# Fold 4 started at Sun Oct 13 18:26:55 2019
# Training until validation scores don't improve for 2000 rounds
# [1000]	training's auc: 0.863217	valid_1's auc: 0.828797
# [2000]	training's auc: 0.896656	valid_1's auc: 0.837807
# [3000]	training's auc: 0.920542	valid_1's auc: 0.841106
# [4000]	training's auc: 0.93877	valid_1's auc: 0.84208
# [5000]	training's auc: 0.953256	valid_1's auc: 0.842639
# [6000]	training's auc: 0.96499	valid_1's auc: 0.842729
# [7000]	training's auc: 0.974247	valid_1's auc: 0.842854
# [8000]	training's auc: 0.981346	valid_1's auc: 0.842786
# Early stopping, best iteration is:
# [6730]	training's auc: 0.971943	valid_1's auc: 0.84287
# CV mean score: 0.8428, std: 0.0044.
# Fold 0 started at Sun Oct 13 18:27:31 2019
# Training until validation scores don't improve for 2000 rounds
# [1000]	training's auc: 0.862915	valid_1's auc: 0.828459
# [2000]	training's auc: 0.896343	valid_1's auc: 0.838224
# [3000]	training's auc: 0.920039	valid_1's auc: 0.842016
# [4000]	training's auc: 0.938388	valid_1's auc: 0.843755
# [5000]	training's auc: 0.953087	valid_1's auc: 0.844524
# [6000]	training's auc: 0.964874	valid_1's auc: 0.844809
# [7000]	training's auc: 0.974066	valid_1's auc: 0.844877
# [8000]	training's auc: 0.981211	valid_1's auc: 0.844818
# Early stopping, best iteration is:
# [6893]	training's auc: 0.973232	valid_1's auc: 0.844956
# Fold 1 started at Sun Oct 13 18:28:07 2019
# Training until validation scores don't improve for 2000 rounds
# [1000]	training's auc: 0.86543	valid_1's auc: 0.817777
# [2000]	training's auc: 0.898688	valid_1's auc: 0.827249
# [3000]	training's auc: 0.922165	valid_1's auc: 0.831183
# [4000]	training's auc: 0.940076	valid_1's auc: 0.833071
# [5000]	training's auc: 0.954237	valid_1's auc: 0.834088
# [6000]	training's auc: 0.965425	valid_1's auc: 0.83435
# [7000]	training's auc: 0.974314	valid_1's auc: 0.834368
# [8000]	training's auc: 0.981312	valid_1's auc: 0.834386
# [9000]	training's auc: 0.986607	valid_1's auc: 0.834194
# Early stopping, best iteration is:
# [7408]	training's auc: 0.977369	valid_1's auc: 0.834493
# Fold 2 started at Sun Oct 13 18:28:46 2019
# Training until validation scores don't improve for 2000 rounds
# [1000]	training's auc: 0.862758	valid_1's auc: 0.833685
# [2000]	training's auc: 0.896726	valid_1's auc: 0.842027
# [3000]	training's auc: 0.920625	valid_1's auc: 0.844531
# [4000]	training's auc: 0.938797	valid_1's auc: 0.845868
# [5000]	training's auc: 0.953326	valid_1's auc: 0.846523
# [6000]	training's auc: 0.965157	valid_1's auc: 0.846477
# [7000]	training's auc: 0.97435	valid_1's auc: 0.846614
# [8000]	training's auc: 0.981461	valid_1's auc: 0.846285
# Early stopping, best iteration is:
# [6774]	training's auc: 0.972482	valid_1's auc: 0.846662
# Fold 3 started at Sun Oct 13 18:29:23 2019
# Training until validation scores don't improve for 2000 rounds
# [1000]	training's auc: 0.862597	valid_1's auc: 0.831818
# [2000]	training's auc: 0.896398	valid_1's auc: 0.840394
# [3000]	training's auc: 0.920399	valid_1's auc: 0.843351
# [4000]	training's auc: 0.938602	valid_1's auc: 0.844334
# [5000]	training's auc: 0.953109	valid_1's auc: 0.844841
# [6000]	training's auc: 0.964734	valid_1's auc: 0.844935
# [7000]	training's auc: 0.973884	valid_1's auc: 0.844838
# Early stopping, best iteration is:
# [5626]	training's auc: 0.960751	valid_1's auc: 0.845051
# Fold 4 started at Sun Oct 13 18:29:55 2019
# Training until validation scores don't improve for 2000 rounds
# [1000]	training's auc: 0.863178	valid_1's auc: 0.828847
# [2000]	training's auc: 0.896562	valid_1's auc: 0.837807
# [3000]	training's auc: 0.920319	valid_1's auc: 0.841237
# [4000]	training's auc: 0.938501	valid_1's auc: 0.842192
# [5000]	training's auc: 0.952889	valid_1's auc: 0.842762
# [6000]	training's auc: 0.964565	valid_1's auc: 0.84294
# [7000]	training's auc: 0.973856	valid_1's auc: 0.842853
# Early stopping, best iteration is:
# [5780]	training's auc: 0.962285	valid_1's auc: 0.842978
# CV mean score: 0.8428, std: 0.0043.
# Fold 0 started at Sun Oct 13 18:30:28 2019
# Training until validation scores don't improve for 2000 rounds
# [1000]	training's auc: 0.862847	valid_1's auc: 0.828358
# [2000]	training's auc: 0.8961	valid_1's auc: 0.838106
# [3000]	training's auc: 0.919749	valid_1's auc: 0.842004
# [4000]	training's auc: 0.937958	valid_1's auc: 0.843687
# [5000]	training's auc: 0.952559	valid_1's auc: 0.844307
# [6000]	training's auc: 0.964303	valid_1's auc: 0.844875
# [7000]	training's auc: 0.973561	valid_1's auc: 0.844843
# [8000]	training's auc: 0.980829	valid_1's auc: 0.844732
# Early stopping, best iteration is:
# [6482]	training's auc: 0.969093	valid_1's auc: 0.845022
# Fold 1 started at Sun Oct 13 18:31:03 2019
# Training until validation scores don't improve for 2000 rounds
# [1000]	training's auc: 0.865414	valid_1's auc: 0.817683
# [2000]	training's auc: 0.898488	valid_1's auc: 0.827375
# [3000]	training's auc: 0.921878	valid_1's auc: 0.831243
# [4000]	training's auc: 0.939755	valid_1's auc: 0.832974
# [5000]	training's auc: 0.953951	valid_1's auc: 0.833869
# [6000]	training's auc: 0.965171	valid_1's auc: 0.834035
# [7000]	training's auc: 0.974032	valid_1's auc: 0.834126
# [8000]	training's auc: 0.980965	valid_1's auc: 0.834325
# [9000]	training's auc: 0.986356	valid_1's auc: 0.834145
# [10000]	training's auc: 0.990403	valid_1's auc: 0.834056
# Early stopping, best iteration is:
# [8258]	training's auc: 0.982461	valid_1's auc: 0.834421
# Fold 2 started at Sun Oct 13 18:31:45 2019
# Training until validation scores don't improve for 2000 rounds
# [1000]	training's auc: 0.862693	valid_1's auc: 0.833599
# [2000]	training's auc: 0.896549	valid_1's auc: 0.841764
# [3000]	training's auc: 0.920352	valid_1's auc: 0.844469
# [4000]	training's auc: 0.938388	valid_1's auc: 0.845969
# [5000]	training's auc: 0.952917	valid_1's auc: 0.846461
# [6000]	training's auc: 0.964795	valid_1's auc: 0.846329
# [7000]	training's auc: 0.97409	valid_1's auc: 0.846275
# Early stopping, best iteration is:
# [5203]	training's auc: 0.955589	valid_1's auc: 0.846544
# Fold 3 started at Sun Oct 13 18:32:15 2019
# Training until validation scores don't improve for 2000 rounds
# [1000]	training's auc: 0.86252	valid_1's auc: 0.831796
# [2000]	training's auc: 0.89625	valid_1's auc: 0.840443
# [3000]	training's auc: 0.920155	valid_1's auc: 0.843536
# [4000]	training's auc: 0.938322	valid_1's auc: 0.844618
# [5000]	training's auc: 0.9528	valid_1's auc: 0.844985
# [6000]	training's auc: 0.964536	valid_1's auc: 0.844918
# [7000]	training's auc: 0.973702	valid_1's auc: 0.844701
# Early stopping, best iteration is:
# [5675]	training's auc: 0.961015	valid_1's auc: 0.845055
# Fold 4 started at Sun Oct 13 18:32:48 2019
# Training until validation scores don't improve for 2000 rounds
# [1000]	training's auc: 0.863088	valid_1's auc: 0.828749
# [2000]	training's auc: 0.896265	valid_1's auc: 0.837673
# [3000]	training's auc: 0.920019	valid_1's auc: 0.840977
# [4000]	training's auc: 0.938139	valid_1's auc: 0.842046
# [5000]	training's auc: 0.952545	valid_1's auc: 0.842389
# [6000]	training's auc: 0.964168	valid_1's auc: 0.842578
# [7000]	training's auc: 0.97346	valid_1's auc: 0.842392
# [8000]	training's auc: 0.98062	valid_1's auc: 0.842296
# Early stopping, best iteration is:
# [6065]	training's auc: 0.964812	valid_1's auc: 0.842606
# CV mean score: 0.8427, std: 0.0043.
# Fold 0 started at Sun Oct 13 18:33:21 2019
# Training until validation scores don't improve for 2000 rounds
# [1000]	training's auc: 0.862724	valid_1's auc: 0.828483
# [2000]	training's auc: 0.896	valid_1's auc: 0.838474
# [3000]	training's auc: 0.919507	valid_1's auc: 0.842419
# [4000]	training's auc: 0.93776	valid_1's auc: 0.844186
# [5000]	training's auc: 0.952316	valid_1's auc: 0.844895
# [6000]	training's auc: 0.964056	valid_1's auc: 0.845292
# [7000]	training's auc: 0.973349	valid_1's auc: 0.845532
# [8000]	training's auc: 0.980507	valid_1's auc: 0.845435
# [9000]	training's auc: 0.986031	valid_1's auc: 0.845251
# Early stopping, best iteration is:
# [7124]	training's auc: 0.974352	valid_1's auc: 0.845602
# Fold 1 started at Sun Oct 13 18:33:59 2019
# Training until validation scores don't improve for 2000 rounds
# [1000]	training's auc: 0.865267	valid_1's auc: 0.817733
# [2000]	training's auc: 0.898295	valid_1's auc: 0.827406
# [3000]	training's auc: 0.921651	valid_1's auc: 0.831122
# [4000]	training's auc: 0.939487	valid_1's auc: 0.832973
# [5000]	training's auc: 0.953591	valid_1's auc: 0.8338
# [6000]	training's auc: 0.964877	valid_1's auc: 0.833849
# [7000]	training's auc: 0.973784	valid_1's auc: 0.834032
# [8000]	training's auc: 0.980786	valid_1's auc: 0.833952
# [9000]	training's auc: 0.986176	valid_1's auc: 0.833698
# Early stopping, best iteration is:
# [7073]	training's auc: 0.974368	valid_1's auc: 0.834076
# Fold 2 started at Sun Oct 13 18:34:37 2019
# Training until validation scores don't improve for 2000 rounds
# [1000]	training's auc: 0.862622	valid_1's auc: 0.833721
# [2000]	training's auc: 0.896384	valid_1's auc: 0.841822
# [3000]	training's auc: 0.92009	valid_1's auc: 0.844396
# [4000]	training's auc: 0.938012	valid_1's auc: 0.8457
# [5000]	training's auc: 0.952589	valid_1's auc: 0.845938
# [6000]	training's auc: 0.964425	valid_1's auc: 0.845938
# [7000]	training's auc: 0.973682	valid_1's auc: 0.845813
# Early stopping, best iteration is:
# [5266]	training's auc: 0.956059	valid_1's auc: 0.846093
# Fold 3 started at Sun Oct 13 18:35:08 2019
# Training until validation scores don't improve for 2000 rounds
# [1000]	training's auc: 0.862433	valid_1's auc: 0.831846
# [2000]	training's auc: 0.896009	valid_1's auc: 0.84041
# [3000]	training's auc: 0.919895	valid_1's auc: 0.843315
# [4000]	training's auc: 0.937984	valid_1's auc: 0.844492
# [5000]	training's auc: 0.952577	valid_1's auc: 0.844909
# [6000]	training's auc: 0.964247	valid_1's auc: 0.845047
# [7000]	training's auc: 0.973465	valid_1's auc: 0.844837
# Early stopping, best iteration is:
# [5883]	training's auc: 0.963058	valid_1's auc: 0.845072
# Fold 4 started at Sun Oct 13 18:35:42 2019
# Training until validation scores don't improve for 2000 rounds
# [1000]	training's auc: 0.86292	valid_1's auc: 0.828695
# [2000]	training's auc: 0.896116	valid_1's auc: 0.83779
# [3000]	training's auc: 0.919748	valid_1's auc: 0.841102
# [4000]	training's auc: 0.937788	valid_1's auc: 0.842061
# [5000]	training's auc: 0.952168	valid_1's auc: 0.842464
# [6000]	training's auc: 0.963822	valid_1's auc: 0.84277
# [7000]	training's auc: 0.973163	valid_1's auc: 0.842604
# [8000]	training's auc: 0.980376	valid_1's auc: 0.842408
# Early stopping, best iteration is:
# [6078]	training's auc: 0.964622	valid_1's auc: 0.842896
# CV mean score: 0.8427, std: 0.0045.
# Fold 0 started at Sun Oct 13 18:36:16 2019
# Training until validation scores don't improve for 2000 rounds
# [1000]	training's auc: 0.862605	valid_1's auc: 0.828361
# [2000]	training's auc: 0.895749	valid_1's auc: 0.8384
# [3000]	training's auc: 0.919123	valid_1's auc: 0.842208
# ...
# [2000]	training's auc: 0.89555	valid_1's auc: 0.838453
# [3000]	training's auc: 0.918891	valid_1's auc: 0.842439
# [4000]	training's auc: 0.937035	valid_1's auc: 0.843875
# [5000]	training's auc: 0.951525	valid_1's auc: 0.844682
# [6000]	training's auc: 0.963197	valid_1's auc: 0.84507
# [7000]	training's auc: 0.972489	valid_1's auc: 0.845095
# [8000]	training's auc: 0.979781	valid_1's auc: 0.844911
# Early stopping, best iteration is:
# [6802]	training's auc: 0.970828	valid_1's auc: 0.845296
# Fold 1 started at Sun Oct 13 18:39:43 2019
# Training until validation scores don't improve for 2000 rounds
# [1000]	training's auc: 0.865123	valid_1's auc: 0.817754
# [2000]	training's auc: 0.897929	valid_1's auc: 0.827439
# [3000]	training's auc: 0.921183	valid_1's auc: 0.831209
# [4000]	training's auc: 0.938991	valid_1's auc: 0.833122
# [5000]	training's auc: 0.953074	valid_1's auc: 0.833923
# [6000]	training's auc: 0.964167	valid_1's auc: 0.83414
# [7000]	training's auc: 0.973105	valid_1's auc: 0.834143
# [8000]	training's auc: 0.980072	valid_1's auc: 0.834172
# [9000]	training's auc: 0.98548	valid_1's auc: 0.834152
# Early stopping, best iteration is:
# [7099]	training's auc: 0.973866	valid_1's auc: 0.834183
# Fold 2 started at Sun Oct 13 18:40:21 2019
# Training until validation scores don't improve for 2000 rounds
# [1000]	training's auc: 0.862379	valid_1's auc: 0.833722
# [2000]	training's auc: 0.895978	valid_1's auc: 0.842158
# [3000]	training's auc: 0.919505	valid_1's auc: 0.844739
# [4000]	training's auc: 0.937434	valid_1's auc: 0.845917
# [5000]	training's auc: 0.951828	valid_1's auc: 0.846299
# [6000]	training's auc: 0.963618	valid_1's auc: 0.84651
# [7000]	training's auc: 0.972939	valid_1's auc: 0.84639
# [8000]	training's auc: 0.980225	valid_1's auc: 0.846067
# Early stopping, best iteration is:
# [6321]	training's auc: 0.966975	valid_1's auc: 0.84658
# Fold 3 started at Sun Oct 13 18:40:56 2019
# Training until validation scores don't improve for 2000 rounds
# [1000]	training's auc: 0.862237	valid_1's auc: 0.831853
# [2000]	training's auc: 0.895669	valid_1's auc: 0.840466
# [3000]	training's auc: 0.919396	valid_1's auc: 0.843282
# [4000]	training's auc: 0.93727	valid_1's auc: 0.844498
# [5000]	training's auc: 0.95168	valid_1's auc: 0.844658
# [6000]	training's auc: 0.963341	valid_1's auc: 0.844821
# [7000]	training's auc: 0.9728	valid_1's auc: 0.844504
# Early stopping, best iteration is:
# [5765]	training's auc: 0.960911	valid_1's auc: 0.844922
# Fold 4 started at Sun Oct 13 18:41:29 2019
# Training until validation scores don't improve for 2000 rounds
# [1000]	training's auc: 0.862732	valid_1's auc: 0.828762
# [2000]	training's auc: 0.895744	valid_1's auc: 0.837941
# [3000]	training's auc: 0.919267	valid_1's auc: 0.841175
# [4000]	training's auc: 0.937282	valid_1's auc: 0.84202
# [5000]	training's auc: 0.951593	valid_1's auc: 0.842643
# [6000]	training's auc: 0.963217	valid_1's auc: 0.842842
# [7000]	training's auc: 0.972465	valid_1's auc: 0.842892
# [8000]	training's auc: 0.979726	valid_1's auc: 0.842753
# Early stopping, best iteration is:
# [6859]	training's auc: 0.971282	valid_1's auc: 0.842984
# CV mean score: 0.8428, std: 0.0045.
# Fold 0 started at Sun Oct 13 18:42:05 2019
# Training until validation scores don't improve for 2000 rounds
# [1000]	training's auc: 0.862467	valid_1's auc: 0.828308
# [2000]	training's auc: 0.895455	valid_1's auc: 0.83852
# [3000]	training's auc: 0.918696	valid_1's auc: 0.8428
# [4000]	training's auc: 0.936801	valid_1's auc: 0.84443
# [5000]	training's auc: 0.951277	valid_1's auc: 0.845141
# [6000]	training's auc: 0.962998	valid_1's auc: 0.845475
# [7000]	training's auc: 0.972278	valid_1's auc: 0.845822
# [8000]	training's auc: 0.979512	valid_1's auc: 0.845735
# [9000]	training's auc: 0.985228	valid_1's auc: 0.845594
# Early stopping, best iteration is:
# [7072]	training's auc: 0.972858	valid_1's auc: 0.845845
# Fold 1 started at Sun Oct 13 18:42:42 2019
# Training until validation scores don't improve for 2000 rounds
# [1000]	training's auc: 0.865062	valid_1's auc: 0.817753
# [2000]	training's auc: 0.89778	valid_1's auc: 0.827377
# [3000]	training's auc: 0.920978	valid_1's auc: 0.831069
# [4000]	training's auc: 0.938703	valid_1's auc: 0.833042
# [5000]	training's auc: 0.952665	valid_1's auc: 0.833961
# [6000]	training's auc: 0.963817	valid_1's auc: 0.834196
# [7000]	training's auc: 0.972741	valid_1's auc: 0.834298
# [8000]	training's auc: 0.979693	valid_1's auc: 0.834288
# [9000]	training's auc: 0.985129	valid_1's auc: 0.834147
# Early stopping, best iteration is:
# [7798]	training's auc: 0.978399	valid_1's auc: 0.834371
# Fold 2 started at Sun Oct 13 18:43:23 2019
# Training until validation scores don't improve for 2000 rounds
# [1000]	training's auc: 0.862262	valid_1's auc: 0.833747
# [2000]	training's auc: 0.89578	valid_1's auc: 0.842124
# [3000]	training's auc: 0.919279	valid_1's auc: 0.844563
# [4000]	training's auc: 0.937208	valid_1's auc: 0.845697
# [5000]	training's auc: 0.951768	valid_1's auc: 0.845969
# [6000]	training's auc: 0.963534	valid_1's auc: 0.846071
# [7000]	training's auc: 0.972868	valid_1's auc: 0.845955
# Early stopping, best iteration is:
# [5479]	training's auc: 0.957742	valid_1's auc: 0.846258
# Fold 3 started at Sun Oct 13 18:43:55 2019
# Training until validation scores don't improve for 2000 rounds
# [1000]	training's auc: 0.862128	valid_1's auc: 0.831861
# [2000]	training's auc: 0.895456	valid_1's auc: 0.840601
# [3000]	training's auc: 0.919151	valid_1's auc: 0.843457
# [4000]	training's auc: 0.937049	valid_1's auc: 0.844529
# [5000]	training's auc: 0.951417	valid_1's auc: 0.844829
# [6000]	training's auc: 0.962991	valid_1's auc: 0.844995
# [7000]	training's auc: 0.972221	valid_1's auc: 0.844622
# Early stopping, best iteration is:
# [5715]	training's auc: 0.959946	valid_1's auc: 0.845095
# Fold 4 started at Sun Oct 13 18:44:28 2019
# Training until validation scores don't improve for 2000 rounds
# [1000]	training's auc: 0.862618	valid_1's auc: 0.828773
# [2000]	training's auc: 0.895528	valid_1's auc: 0.83781
# [3000]	training's auc: 0.918979	valid_1's auc: 0.841091
# [4000]	training's auc: 0.936854	valid_1's auc: 0.842366
# [5000]	training's auc: 0.951063	valid_1's auc: 0.842748
# [6000]	training's auc: 0.962675	valid_1's auc: 0.842866
# [7000]	training's auc: 0.971976	valid_1's auc: 0.842716
# [8000]	training's auc: 0.97928	valid_1's auc: 0.842484
# Early stopping, best iteration is:
# [6221]	training's auc: 0.964876	valid_1's auc: 0.842928
# CV mean score: 0.8429, std: 0.0044.
# Fold 0 started at Sun Oct 13 18:45:03 2019
# Training until validation scores don't improve for 2000 rounds
# [1000]	training's auc: 0.862413	valid_1's auc: 0.828369
# [2000]	training's auc: 0.895264	valid_1's auc: 0.838516
# [3000]	training's auc: 0.918505	valid_1's auc: 0.842708
# [4000]	training's auc: 0.936466	valid_1's auc: 0.844317
# [5000]	training's auc: 0.951009	valid_1's auc: 0.845161
# [6000]	training's auc: 0.962721	valid_1's auc: 0.845415
# [7000]	training's auc: 0.972042	valid_1's auc: 0.845471
# [8000]	training's auc: 0.979387	valid_1's auc: 0.845389
# Early stopping, best iteration is:
# [6945]	training's auc: 0.971612	valid_1's auc: 0.845529
# Fold 1 started at Sun Oct 13 18:45:40 2019
# Training until validation scores don't improve for 2000 rounds
# [1000]	training's auc: 0.864891	valid_1's auc: 0.817736
# [2000]	training's auc: 0.897544	valid_1's auc: 0.827406
# [3000]	training's auc: 0.920688	valid_1's auc: 0.831071
# [4000]	training's auc: 0.938311	valid_1's auc: 0.832991
# [5000]	training's auc: 0.952183	valid_1's auc: 0.833545
# [6000]	training's auc: 0.963315	valid_1's auc: 0.833711
# [7000]	training's auc: 0.972254	valid_1's auc: 0.833564
# [8000]	training's auc: 0.979299	valid_1's auc: 0.833599
# Early stopping, best iteration is:
# [6174]	training's auc: 0.964964	valid_1's auc: 0.833836
# Fold 2 started at Sun Oct 13 18:46:15 2019
# Training until validation scores don't improve for 2000 rounds
# [1000]	training's auc: 0.862179	valid_1's auc: 0.833756
# [2000]	training's auc: 0.895506	valid_1's auc: 0.84214
# [3000]	training's auc: 0.919011	valid_1's auc: 0.844714
# [4000]	training's auc: 0.93681	valid_1's auc: 0.846142
# [5000]	training's auc: 0.951484	valid_1's auc: 0.8464
# [6000]	training's auc: 0.963175	valid_1's auc: 0.846581
# [7000]	training's auc: 0.972485	valid_1's auc: 0.846396
# Early stopping, best iteration is:
# [5754]	training's auc: 0.960668	valid_1's auc: 0.846703
# Fold 3 started at Sun Oct 13 18:47:04 2019
# Training until validation scores don't improve for 2000 rounds
# [1000]	training's auc: 0.861986	valid_1's auc: 0.831796
# [2000]	training's auc: 0.895245	valid_1's auc: 0.840672
# [3000]	training's auc: 0.918811	valid_1's auc: 0.843496
# [4000]	training's auc: 0.93665	valid_1's auc: 0.844895
# [5000]	training's auc: 0.951058	valid_1's auc: 0.845195
# [6000]	training's auc: 0.962844	valid_1's auc: 0.845327
# [7000]	training's auc: 0.97214	valid_1's auc: 0.844902
# Early stopping, best iteration is:
# [5909]	training's auc: 0.961883	valid_1's auc: 0.845425
# Fold 4 started at Sun Oct 13 18:47:37 2019
# Training until validation scores don't improve for 2000 rounds
# [1000]	training's auc: 0.86254	valid_1's auc: 0.82867
# [2000]	training's auc: 0.895436	valid_1's auc: 0.837935
# [3000]	training's auc: 0.918781	valid_1's auc: 0.841213
# [4000]	training's auc: 0.936636	valid_1's auc: 0.842333
# [5000]	training's auc: 0.950937	valid_1's auc: 0.842559
# [6000]	training's auc: 0.962496	valid_1's auc: 0.842797
# [7000]	training's auc: 0.971895	valid_1's auc: 0.842859
# [8000]	training's auc: 0.979155	valid_1's auc: 0.842604
# Early stopping, best iteration is:
# [6766]	training's auc: 0.969881	valid_1's auc: 0.842998
# CV mean score: 0.8429, std: 0.0047.
# Fold 0 started at Sun Oct 13 18:48:13 2019
# Training until validation scores don't improve for 2000 rounds
# [1000]	training's auc: 0.862296	valid_1's auc: 0.82819
# [2000]	training's auc: 0.895075	valid_1's auc: 0.838389
# [3000]	training's auc: 0.918208	valid_1's auc: 0.842571
# [4000]	training's auc: 0.936101	valid_1's auc: 0.844432
# [5000]	training's auc: 0.950709	valid_1's auc: 0.845278
# [6000]	training's auc: 0.962449	valid_1's auc: 0.845793
# [7000]	training's auc: 0.971718	valid_1's auc: 0.845747
# [8000]	training's auc: 0.979062	valid_1's auc: 0.845704
# Early stopping, best iteration is:
# [6651]	training's auc: 0.968664	valid_1's auc: 0.845882
# Fold 1 started at Sun Oct 13 18:48:49 2019
# Training until validation scores don't improve for 2000 rounds
# [1000]	training's auc: 0.864891	valid_1's auc: 0.817669
# [2000]	training's auc: 0.897407	valid_1's auc: 0.827315
# [3000]	training's auc: 0.920544	valid_1's auc: 0.831182
# [4000]	training's auc: 0.938097	valid_1's auc: 0.833022
# [5000]	training's auc: 0.951965	valid_1's auc: 0.833948
# [6000]	training's auc: 0.96323	valid_1's auc: 0.834081
# [7000]	training's auc: 0.972073	valid_1's auc: 0.834104
# [8000]	training's auc: 0.979244	valid_1's auc: 0.834005
# Early stopping, best iteration is:
# [6701]	training's auc: 0.969685	valid_1's auc: 0.834169
# Fold 2 started at Sun Oct 13 18:49:28 2019
# Training until validation scores don't improve for 2000 rounds
# [1000]	training's auc: 0.862033	valid_1's auc: 0.833758
# [2000]	training's auc: 0.895355	valid_1's auc: 0.842264
# [3000]	training's auc: 0.91875	valid_1's auc: 0.84487
# [4000]	training's auc: 0.936528	valid_1's auc: 0.846262
# [5000]	training's auc: 0.951069	valid_1's auc: 0.846484
# [6000]	training's auc: 0.962822	valid_1's auc: 0.846672
# [7000]	training's auc: 0.972182	valid_1's auc: 0.846453
# Early stopping, best iteration is:
# [5936]	training's auc: 0.962191	valid_1's auc: 0.846748
# Fold 3 started at Sun Oct 13 18:50:02 2019
# Training until validation scores don't improve for 2000 rounds
# [1000]	training's auc: 0.861917	valid_1's auc: 0.831617
# [2000]	training's auc: 0.895007	valid_1's auc: 0.840585
# [3000]	training's auc: 0.91855	valid_1's auc: 0.843683
# [4000]	training's auc: 0.936365	valid_1's auc: 0.844765
# [5000]	training's auc: 0.950826	valid_1's auc: 0.845355
# [6000]	training's auc: 0.962447	valid_1's auc: 0.84538
# [7000]	training's auc: 0.971729	valid_1's auc: 0.845336
# [8000]	training's auc: 0.978953	valid_1's auc: 0.84517
# Early stopping, best iteration is:
# [6390]	training's auc: 0.966341	valid_1's auc: 0.845522
# Fold 4 started at Sun Oct 13 18:50:38 2019
# Training until validation scores don't improve for 2000 rounds
# [1000]	training's auc: 0.862467	valid_1's auc: 0.828774
# [2000]	training's auc: 0.895243	valid_1's auc: 0.837875
# [3000]	training's auc: 0.918492	valid_1's auc: 0.841227
# [4000]	training's auc: 0.936423	valid_1's auc: 0.842238
# [5000]	training's auc: 0.950497	valid_1's auc: 0.84258
# [6000]	training's auc: 0.962005	valid_1's auc: 0.842972
# [7000]	training's auc: 0.971414	valid_1's auc: 0.842996
# [8000]	training's auc: 0.978773	valid_1's auc: 0.843063
# [9000]	training's auc: 0.984523	valid_1's auc: 0.842949
# [10000]	training's auc: 0.989041	valid_1's auc: 0.842591
# Early stopping, best iteration is:
# [8232]	training's auc: 0.980207	valid_1's auc: 0.8431
# CV mean score: 0.8431, std: 0.0046.
# Fold 0 started at Sun Oct 13 18:51:20 2019
# Training until validation scores don't improve for 2000 rounds
# [1000]	training's auc: 0.862208	valid_1's auc: 0.828163
# [2000]	training's auc: 0.894957	valid_1's auc: 0.838435
# [3000]	training's auc: 0.918049	valid_1's auc: 0.842831
# [4000]	training's auc: 0.935853	valid_1's auc: 0.844413
# [5000]	training's auc: 0.950239	valid_1's auc: 0.845154
# [6000]	training's auc: 0.962055	valid_1's auc: 0.845491
# [7000]	training's auc: 0.971435	valid_1's auc: 0.845692
# [8000]	training's auc: 0.978866	valid_1's auc: 0.845596
# [9000]	training's auc: 0.984452	valid_1's auc: 0.845553
# Early stopping, best iteration is:
# [7091]	training's auc: 0.972203	valid_1's auc: 0.845762
# Fold 1 started at Sun Oct 13 18:51:58 2019
# Training until validation scores don't improve for 2000 rounds
# [1000]	training's auc: 0.864812	valid_1's auc: 0.817686
# [2000]	training's auc: 0.897283	valid_1's auc: 0.82739
# [3000]	training's auc: 0.920335	valid_1's auc: 0.831291
# [4000]	training's auc: 0.937929	valid_1's auc: 0.8332
# [5000]	training's auc: 0.951723	valid_1's auc: 0.833967
# [6000]	training's auc: 0.963025	valid_1's auc: 0.833775
# [7000]	training's auc: 0.971951	valid_1's auc: 0.833916
# Early stopping, best iteration is:
# [5012]	training's auc: 0.95187	valid_1's auc: 0.833977
# Fold 2 started at Sun Oct 13 18:52:29 2019
# Training until validation scores don't improve for 2000 rounds
# [1000]	training's auc: 0.861935	valid_1's auc: 0.833772
# [2000]	training's auc: 0.895111	valid_1's auc: 0.842145
# [3000]	training's auc: 0.91847	valid_1's auc: 0.844662
# [4000]	training's auc: 0.936225	valid_1's auc: 0.845933
# [5000]	training's auc: 0.95062	valid_1's auc: 0.846278
# [6000]	training's auc: 0.962349	valid_1's auc: 0.846219
# [7000]	training's auc: 0.971643	valid_1's auc: 0.846272
# Early stopping, best iteration is:
# [5391]	training's auc: 0.955551	valid_1's auc: 0.846426
# Fold 3 started at Sun Oct 13 18:53:01 2019
# Training until validation scores don't improve for 2000 rounds
# [1000]	training's auc: 0.862552	valid_1's auc: 0.831705
# [2000]	training's auc: 0.895044	valid_1's auc: 0.83986
# [3000]	training's auc: 0.918438	valid_1's auc: 0.843279
# [4000]	training's auc: 0.936253	valid_1's auc: 0.844645
# [5000]	training's auc: 0.950697	valid_1's auc: 0.844885
# [6000]	training's auc: 0.962069	valid_1's auc: 0.844976
# [7000]	training's auc: 0.971482	valid_1's auc: 0.844816
# Early stopping, best iteration is:
# [5875]	training's auc: 0.960841	valid_1's auc: 0.845055
# Fold 4 started at Sun Oct 13 18:53:34 2019
# Training until validation scores don't improve for 2000 rounds
# [1000]	training's auc: 0.862331	valid_1's auc: 0.828738
# [2000]	training's auc: 0.894942	valid_1's auc: 0.837845
# [3000]	training's auc: 0.918224	valid_1's auc: 0.841309
# [4000]	training's auc: 0.935896	valid_1's auc: 0.84262
# [5000]	training's auc: 0.950091	valid_1's auc: 0.842901
# [6000]	training's auc: 0.961806	valid_1's auc: 0.843153
# [7000]	training's auc: 0.97108	valid_1's auc: 0.843257
# [8000]	training's auc: 0.978386	valid_1's auc: 0.842895
# [9000]	training's auc: 0.984144	valid_1's auc: 0.842789
# Early stopping, best iteration is:
# [7006]	training's auc: 0.971144	valid_1's auc: 0.843279
# CV mean score: 0.8429, std: 0.0046.

# %%
results
# Out:
# [{0.842767067361477, 40},
#  {0.8426052702422556, 45},
#  {0.8428262842607918, 50},
#  {0.8427527205714961, 55},
#  {0.8426099136089036, 60},
#  {0.8427073962186556, 65},
#  {0.8428374795623071, 70},
#  {0.842833956270564, 75},
#  {0.842764779145312, 80},
#  {0.8429007717649195, 85},
#  {0.8427578630824872, 90},
#  {0.8428278794252169, 95},
#  {0.8427292833737272, 100},
#  {0.8427477653378717, 105},
#  {0.8426913821234152, 110},
#  {0.8427931163410152, 115},
#  {0.8428993151862694, 120},
#  {0.8428980858093148, 125},
#  {0.8430842538044512, 130},
#  {0.8428998345769021, 135}]

# %%
results
# Out:
# [{0.8432429975380094, 20},
#  {0.843054275020943, 22},
#  {0.8429844384510995, 24},
#  {0.843061104749534, 26},
#  {0.8428671804499069, 28},
#  {0.843085448479162, 30},
#  {0.8429743874995163, 32},
#  {0.8429743874995163, 34},
#  {0.8429743874995163, 36},
#  {0.8429743874995163, 38}]

# %%
#[{0.8432429975380094, 20},
# {0.843054275020943, 22},
# {0.8429844384510995, 24},
# {0.843061104749534, 26},
# {0.8428671804499069, 28},
# {0.843085448479162, 30},
# {0.8429743874995163, 32},
# {0.8429743874995163, 34},
# {0.8429743874995163, 36},
# {0.8429743874995163, 38}]
