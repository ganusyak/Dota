# %%
import ujson as json
from tqdm import tqdm_notebook
import os #to access files
from scipy.sparse import hstack
import time
import lightgbm as lgb
import pandas as pd
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
import seaborn as sns
from matplotlib import pyplot as plt
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import TimeSeriesSplit, cross_val_score, GridSearchCV, StratifiedKFold, KFold
from sklearn.preprocessing import StandardScaler

# %%
PATH_TO_DATA = '../data/'

# %%
df_train_targets = pd.read_csv(os.path.join(PATH_TO_DATA, 
                                            'train_targets.csv'), 
                                   index_col='match_id_hash')

# %%
y = df_train_targets['radiant_win'].values

# %%
def read_matches(matches_file):
    
    MATCHES_COUNT = {
        'test_matches.jsonl': 10000,
        'train_matches.jsonl': 39675,
    }
    _, filename = os.path.split(matches_file)
    total_matches = MATCHES_COUNT.get(filename)
    
    with open(matches_file) as fin:
        for line in tqdm_notebook(fin, total=total_matches):
            yield json.loads(line)

# %%
json_list = [] #store data that are read
number_of_rows = 50 #how many lines to read 

#reading data from .jsonl file
with open(os.path.join(PATH_TO_DATA, 'train_matches.jsonl')) as fin:
    for i in range(number_of_rows):
        line = fin.readline()
        json_list.append(json.loads(line))
        
#how many matches to read. For example I took 1
for i in range(1, 2):
  for j in range(1, 2):#there is 5 players in each team. But I want to look on only one player.
    print(json.dumps(json_list[i]['players'][j], indent=4, sort_keys=True))
# Out:
# {
#     "ability_upgrades":[
#         {
#             "ability":5514,
#             "level":1,
#             "time":232
#         },
#         {
#             "ability":5515,
#             "level":2,
#             "time":304
#         },
#         {
#             "ability":5515,
#             "level":3,
#             "time":322
#         },
#         {
#             "ability":5514,
#             "level":4,
#             "time":391
#         },
#         {
#             "ability":5515,
#             "level":5,
#             "time":499
#         },
#         {
#             "ability":5517,
#             "level":6,
#             "time":581
#         }
#     ],
#     "ability_uses":{
#         "centaur_double_edge":11,
#         "centaur_hoof_stomp":8,
#         "centaur_stampede":2
#     },
#     "account_id_hash":"1c2500195e6ab646fc9371344724aa77",
#     "actions":{
#         "1":3679,
#         "10":183,
#         "11":8,
#         "15":19,
#         "16":18,
#         "19":14,
#         "2":2,
#         "33":183,
#         "4":810,
#         "5":4,
#         "6":42,
#         "7":12,
#         "8":31
#     },
#     "assists":2,
#     "buyback_log":[
#
#     ],
#     "camps_stacked":0,
#     "creeps_stacked":0,
#     "damage":{
#         "npc_dota_badguys_siege":381,
#         "npc_dota_creep_badguys_melee":5062,
#         "npc_dota_creep_badguys_ranged":2595,
#         "npc_dota_creep_goodguys_melee":110,
#         "npc_dota_creep_goodguys_ranged":194,
#         "npc_dota_hero_antimage":1414,
#         "npc_dota_hero_centaur":2496,
#         "npc_dota_hero_clinkz":155,
#         "npc_dota_hero_enchantress":1031,
#         "npc_dota_neutral_centaur_khan":338,
#         "npc_dota_neutral_centaur_outrunner":195,
#         "npc_dota_neutral_enraged_wildkin":253,
#         "npc_dota_neutral_satyr_hellcaller":253,
#         "npc_dota_neutral_wildkin":506
#     },
#     "damage_inflictor":{
#         "centaur_double_edge":1332,
#         "centaur_hoof_stomp":558,
#         "centaur_stampede":77,
#         "null":633
#     },
#     "damage_inflictor_received":{
#         "antimage_mana_void":226,
#         "clinkz_searing_arrows":199,
#         "null":3473,
#         "pudge_rot":48
#     },
#     "damage_taken":{
#         "npc_dota_badguys_siege":41,
#         "npc_dota_creep_badguys_melee":152,
#         "npc_dota_creep_badguys_ranged":103,
#         "npc_dota_hero_antimage":1617,
#         "npc_dota_hero_centaur":2496,
#         "npc_dota_hero_clinkz":392,
#         "npc_dota_hero_enchantress":2252,
#         "npc_dota_hero_pudge":48,
#         "npc_dota_neutral_centaur_outrunner":13
#     },
#     "deaths":1,
#     "denies":3,
#     "dn_t":[
#         0,
#         0,
#         1,
#         2,
#         2,
#         2,
#         3,
#         3,
#         3,
#         3,
#         3
#     ],
#     "firstblood_claimed":0,
#     "gold":3394,
#     "gold_reasons":{
#         "0":996,
#         "1":-125,
#         "11":320,
#         "12":880,
#         "13":801
#     },
#     "gold_t":[
#         41,
#         211,
#         340,
#         589,
#         762,
#         1209,
#         1579,
#         1803,
#         2404,
#         2796,
#         3106
#     ],
#     "healing":{
#         "npc_dota_hero_centaur":265
#     },
#     "health":1352,
#     "hero_hits":{
#         "centaur_double_edge":17,
#         "centaur_hoof_stomp":5,
#         "centaur_stampede":2,
#         "null":13
#     },
#     "hero_id":96,
#     "hero_inventory":[
#         {
#             "cooldown":0,
#             "id":"item_stout_shield"
#         },
#         {
#             "cooldown":0,
#             "id":"item_soul_ring"
#         },
#         {
#             "cooldown":12.9,
#             "id":"item_tranquil_boots",
#             "num_charges":1
#         },
#         {
#             "cooldown":0,
#             "id":"item_chainmail"
#         }
#     ],
#     "hero_name":"npc_dota_hero_centaur",
#     "hero_stash":[
#
#     ],
#     "item_uses":{
#         "enchanted_mango":1,
#         "flask":1,
#         "soul_ring":4,
#         "tango":12,
#         "tpscroll":4
#     },
#     "kill_streaks":{
#         "3":1
#     },
#     "killed":{
#         "npc_dota_creep_badguys_melee":1555,
#         "npc_dota_creep_badguys_ranged":1380,
#         "npc_dota_creep_goodguys_melee":59,
#         "npc_dota_creep_goodguys_ranged":137,
#         "npc_dota_hero_antimage":252,
#         "npc_dota_hero_enchantress":71,
#         "npc_dota_neutral_enraged_wildkin":253,
#         "npc_dota_neutral_wildkin":506
#     },
#     "killed_by":{
#         "npc_dota_hero_antimage":1
#     },
#     "kills":3,
#     "kills_log":[
#         {
#             "key":"npc_dota_hero_antimage",
#             "time":242.168
#         },
#         {
#             "key":"npc_dota_hero_enchantress",
#             "time":334.245
#         },
#         {
#             "key":"npc_dota_hero_antimage",
#             "time":462.814
#         }
#     ],
#     "level":8,
#     "lh":19,
#     "lh_t":[
#         0,
#         0,
#         1,
#         5,
#         8,
#         9,
#         10,
#         13,
#         15,
#         17,
#         19
#     ],
#     "life_state":{
#         "0":1256,
#         "1":7,
#         "2":53
#     },
#     "max_health":1380,
#     "max_hero_hit":{
#         "inflictor":"centaur_double_edge",
#         "key":"npc_dota_hero_antimage",
#         "max":true,
#         "player_slot":1,
#         "slot":1,
#         "time":460.981,
#         "type":"max_hero_hit",
#         "unit":"npc_dota_hero_centaur",
#         "value":247
#     },
#     "max_mana":386.938,
#     "multi_kills":{
#
#     },
#     "nearby_creep_death_count":66,
#     "obs":{
#
#     },
#     "obs_left_log":[
#
#     ],
#     "obs_log":[
#
#     ],
#     "obs_placed":0,
#     "observers_placed":0,
#     "pings":{
#         "0":6
#     },
#     "player_slot":1,
#     "pred_vict":false,
#     "purchase":{
#         "boots":1,
#         "chainmail":1,
#         "enchanted_mango":1,
#         "flask":1,
#         "gauntlets":2,
#         "recipe_soul_ring":1,
#         "ring_of_regen":2,
#         "soul_ring":1,
#         "stout_shield":1,
#         "tango":3,
#         "tpscroll":4,
#         "tranquil_boots":1,
#         "wind_lace":1
#     },
#     "purchase_log":[
#         {
#             "key":"stout_shield",
#             "time":-89.781
#         },
#         {
#             "key":"enchanted_mango",
#             "time":-89.781
#         },
#         {
#             "key":"tango",
#             "time":-89.781
#         },
#         {
#             "key":"flask",
#             "time":-89.781
#         },
#         {
#             "key":"tpscroll",
#             "time":-89.781
#         },
#         {
#             "key":"ring_of_regen",
#             "time":176.784
#         },
#         {
#             "key":"gauntlets",
#             "time":176.95
#         },
#         {
#             "key":"gauntlets",
#             "time":177.05
#         },
#         {
#             "key":"tpscroll",
#             "time":199.245
#         },
#         {
#             "key":"tango",
#             "time":257.797
#         },
#         {
#             "key":"soul_ring",
#             "time":279.559
#         },
#         {
#             "key":"boots",
#             "time":343.743
#         },
#         {
#             "key":"wind_lace",
#             "time":370.803
#         },
#         {
#             "key":"tpscroll",
#             "time":398.996
#         },
#         {
#             "key":"ring_of_regen",
#             "time":466.58
#         },
#         {
#             "key":"tango",
#             "time":478.01
#         },
#         {
#             "key":"tranquil_boots",
#             "time":516.701
#         },
#         {
#             "key":"chainmail",
#             "time":590.483
#         },
#         {
#             "key":"tpscroll",
#             "time":629.673
#         }
#     ],
#     "randomed":false,
#     "roshans_killed":0,
#     "rune_pickups":4,
#     "runes":{
#         "5":4
#     },
#     "runes_log":[
#         {
#             "key":5,
#             "time":0.167
#         },
#         {
#             "key":5,
#             "time":475.777
#         },
#         {
#             "key":5,
#             "time":480.176
#         },
#         {
#             "key":5,
#             "time":501.305
#         }
#     ],
#     "sen":{
#
#     },
#     "sen_left_log":[
#
#     ],
#     "sen_log":[
#
#     ],
#     "sen_placed":0,
#     "stuns":8.398,
#     "teamfight_participation":0.312,
#     "times":[
#         0,
#         60,
#         120,
#         180,
#         240,
#         300,
#         360,
#         420,
#         480,
#         540,
#         600
#     ],
#     "towers_killed":0,
#     "x":78,
#     "xp":3897,
#     "xp_reasons":{
#         "1":600,
#         "2":3297
#     },
#     "xp_t":[
#         0,
#         57,
#         452,
#         1022,
#         1103,
#         1641,
#         1991,
#         2388,
#         3061,
#         3327,
#         3769
#     ],
#     "y":166
# }

# %%
for i in range(1, 5): #now we will look at 4 matches
  for j in range(1, 5):#and now will take 5 players
    print(json.dumps(list(map(lambda x: [x][0], json_list[i]['players'][j]['damage'])), indent=4, sort_keys=True))
# Out:
# [
#     "npc_dota_creep_goodguys_ranged",
#     "npc_dota_hero_antimage",
#     "npc_dota_creep_goodguys_melee",
#     "npc_dota_creep_badguys_melee",
#     "npc_dota_creep_badguys_ranged",
#     "npc_dota_hero_centaur",
#     "npc_dota_neutral_wildkin",
#     "npc_dota_neutral_satyr_hellcaller",
#     "npc_dota_neutral_enraged_wildkin",
#     "npc_dota_neutral_centaur_outrunner",
#     "npc_dota_neutral_centaur_khan",
#     "npc_dota_hero_enchantress",
#     "npc_dota_badguys_siege",
#     "npc_dota_hero_clinkz"
# ]
# [
#     "npc_dota_hero_clinkz",
#     "npc_dota_hero_pudge",
#     "npc_dota_creep_badguys_melee",
#     "npc_dota_neutral_gnoll_assassin",
#     "npc_dota_neutral_enraged_wildkin",
#     "npc_dota_creep_goodguys_melee",
#     "npc_dota_creep_goodguys_ranged",
#     "npc_dota_hero_antimage",
#     "npc_dota_hero_enchantress",
#     "npc_dota_neutral_centaur_khan",
#     "npc_dota_creep_badguys_ranged",
#     "npc_dota_badguys_tower1_mid",
#     "npc_dota_badguys_tower2_mid",
#     "npc_dota_badguys_siege"
# ]
# [
#     "npc_dota_creep_goodguys_ranged",
#     "npc_dota_hero_visage",
#     "npc_dota_creep_badguys_melee",
#     "npc_dota_creep_badguys_ranged",
#     "npc_dota_sentry_wards",
#     "npc_dota_creep_goodguys_melee",
#     "npc_dota_hero_pudge",
#     "npc_dota_hero_clinkz",
#     "npc_dota_hero_antimage",
#     "npc_dota_badguys_siege",
#     "npc_dota_badguys_tower1_mid",
#     "npc_dota_hero_enchantress",
#     "npc_dota_neutral_centaur_khan",
#     "npc_dota_badguys_tower2_mid"
# ]
# [
#     "npc_dota_hero_clinkz",
#     "npc_dota_hero_pudge",
#     "npc_dota_creep_goodguys_ranged",
#     "npc_dota_creep_goodguys_melee",
#     "npc_dota_neutral_wildkin",
#     "npc_dota_creep_badguys_melee",
#     "npc_dota_creep_badguys_ranged",
#     "npc_dota_hero_enchantress",
#     "npc_dota_neutral_centaur_khan",
#     "npc_dota_badguys_tower1_mid",
#     "npc_dota_badguys_tower2_mid",
#     "npc_dota_badguys_siege"
# ]
# [
#
# ]
# [
#     "npc_dota_hero_spectre"
# ]
# [
#
# ]
# [
#
# ]
# [
#     "npc_dota_creep_badguys_melee",
#     "npc_dota_hero_juggernaut",
#     "npc_dota_creep_badguys_ranged",
#     "npc_dota_hero_rubick",
#     "npc_dota_neutral_wildkin",
#     "npc_dota_neutral_centaur_outrunner",
#     "npc_dota_neutral_enraged_wildkin",
#     "npc_dota_neutral_centaur_khan",
#     "npc_dota_creep_goodguys_melee",
#     "npc_dota_badguys_siege",
#     "illusion_npc_dota_hero_shredder",
#     "npc_dota_hero_shredder"
# ]
# [
#     "npc_dota_hero_shredder",
#     "npc_dota_creep_badguys_ranged",
#     "npc_dota_creep_goodguys_melee",
#     "npc_dota_creep_badguys_melee",
#     "npc_dota_creep_goodguys_ranged",
#     "npc_dota_badguys_siege",
#     "npc_dota_hero_doom_bringer"
# ]
# [
#     "npc_dota_hero_doom_bringer",
#     "npc_dota_creep_goodguys_melee",
#     "npc_dota_neutral_forest_troll_berserker",
#     "npc_dota_neutral_forest_troll_high_priest",
#     "npc_dota_neutral_enraged_wildkin",
#     "npc_dota_creep_badguys_melee",
#     "npc_dota_creep_badguys_ranged",
#     "npc_dota_badguys_siege",
#     "npc_dota_neutral_ogre_magi"
# ]
# [
#     "npc_dota_creep_badguys_melee",
#     "npc_dota_creep_goodguys_melee",
#     "npc_dota_creep_goodguys_ranged",
#     "npc_dota_creep_badguys_ranged",
#     "npc_dota_hero_doom_bringer"
# ]
# [
#     "npc_dota_hero_antimage",
#     "npc_dota_creep_badguys_melee",
#     "npc_dota_creep_badguys_ranged",
#     "npc_dota_hero_kunkka",
#     "npc_dota_badguys_siege"
# ]
# [
#     "npc_dota_hero_gyrocopter",
#     "npc_dota_creep_badguys_melee",
#     "npc_dota_creep_badguys_ranged",
#     "npc_dota_hero_sniper",
#     "npc_dota_badguys_siege"
# ]
# [
#     "npc_dota_hero_antimage",
#     "npc_dota_creep_badguys_melee",
#     "npc_dota_creep_badguys_ranged",
#     "npc_dota_hero_gyrocopter",
#     "npc_dota_hero_zuus",
#     "npc_dota_badguys_tower1_bot",
#     "npc_dota_badguys_siege"
# ]
# [
#     "npc_dota_creep_badguys_melee",
#     "npc_dota_hero_gyrocopter",
#     "npc_dota_creep_badguys_ranged",
#     "npc_dota_hero_zuus",
#     "npc_dota_badguys_siege"
# ]

# %%
for i in range(1, 5): #now we will look at 4 matches
  for j in range(1, 5):#and now will take 5 players
    print(json.dumps(list(map(lambda x: x, json_list[i]['players'][j]['damage'])), indent=4, sort_keys=True))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-6b3a66c3281e> in <module>
#       1 for i in range(1, 5): #now we will look at 4 matches
#       2   for j in range(1, 5):#and now will take 5 players
# ----> 3     print(json.dumps(list(map(lambda x: x['id'][5:], json_list[i]['players'][j]['damage'])), indent=4, sort_keys=True))
#
# <ipython-input-10-6b3a66c3281e> in <lambda>(x)
#       1 for i in range(1, 5): #now we will look at 4 matches
#       2   for j in range(1, 5):#and now will take 5 players
# ----> 3     print(json.dumps(list(map(lambda x: x['id'][5:], json_list[i]['players'][j]['damage'])), indent=4, sort_keys=True))
#
# TypeError: string indices must be integers

# %%
import collections


def extract_features_csv(match):
    
    row = [
        ('match_id_hash', match['match_id_hash']),
    ]

    for slot, player in enumerate(match['players']):
        if slot < 5:
            player_name = 'r%d' % (slot + 1)
        else:
            player_name = 'd%d' % (slot - 4)

        row.append( (f'{player_name}_items', list(map(lambda x: x['id'][5:], player['hero_inventory'])) ) )
       # row.append( (f'{player_name}_items', list(map(lambda x: x['id'][5:], player[''])) ) )
        #here u can extract other data

    return collections.OrderedDict(row)

    
def extract_targets_csv(match, targets):
    return collections.OrderedDict([('match_id_hash', match['match_id_hash'])] + [
        (field, targets[field])
        for field in ['game_time', 'radiant_win', 'duration', 'time_remaining', 'next_roshan_team']
    ])

# %%
def create_features_from_jsonl(matches_file):
  
    df_new_features = []

    # Process raw data and add new features
    for match in read_matches(matches_file):
        match_id_hash = match['match_id_hash']
        features = extract_features_csv(match)

        df_new_features.append(features)

    df_new_features = pd.DataFrame.from_records(df_new_features).set_index('match_id_hash')
    return df_new_features

# %%
train_df = create_features_from_jsonl(os.path.join(PATH_TO_DATA, 'train_matches.jsonl')).fillna(0)
# Out:
# HBox(children=(IntProgress(value=0, max=39675), HTML(value='')))

# %%
test_df = create_features_from_jsonl(os.path.join(PATH_TO_DATA, 'test_matches.jsonl')).fillna(0)
# Out:
# HBox(children=(IntProgress(value=0, max=10000), HTML(value='')))

# %%
import pickle as pkl

#Better to save extracted data in files, because extracting takes time...
train_df.to_pickle('df_train.pkl')
test_df.to_pickle('df_test.pkl')

# %%
def add_items_dummies(train_df, test_df):
    
    full_df = pd.concat([train_df, test_df], sort=False)
    train_size = train_df.shape[0]

    for team in 'r', 'd':
        players = [f'{team}{i}' for i in range(1, 6)]
        item_columns = [f'{player}_items' for player in players]

        d = pd.get_dummies(full_df[item_columns[0]].apply(pd.Series).stack()).sum(level=0, axis=0)
        dindexes = d.index.values

        for c in item_columns[1:]:
            d = d.add(pd.get_dummies(full_df[c].apply(pd.Series).stack()).sum(level=0, axis=0), fill_value=0)
            d = d.ix[dindexes]

        full_df = pd.concat([full_df, d.add_prefix(f'{team}_item_')], axis=1, sort=False)
        full_df.drop(columns=item_columns, inplace=True)

    train_df = full_df.iloc[:train_size, :]
    test_df = full_df.iloc[train_size:, :]

    return train_df, test_df

# %%
def drop_consumble_items(train_df, test_df):
    
    full_df = pd.concat([train_df, test_df], sort=False)
    train_size = train_df.shape[0]

    for team in 'r', 'd':
        consumble_columns = ['tango', 'tpscroll', 
                             'bottle', 'flask',
                            'enchanted_mango', 'clarity',
                            'faerie_fire', 'ward_observer',
                            'ward_sentry']
        
        starts_with = f'{team}_item_'
        consumble_columns = [starts_with + column for column in consumble_columns]
        full_df.drop(columns=consumble_columns, inplace=True)

    train_df = full_df.iloc[:train_size, :]
    test_df = full_df.iloc[train_size:, :]

    return train_df, test_df

# %%
# %%time
new_train = pd.read_pickle('df_train.pkl')
new_test = pd.read_pickle('df_test.pkl')

new_train, new_test = add_items_dummies(new_train, new_test)
new_train, new_test = drop_consumble_items(new_train, new_test)

target = pd.DataFrame(y)
# Out:
# C:\Users\yganu\Anaconda3\lib\site-packages\ipykernel_launcher.py:15: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   from ipykernel import kernelapp as app
# Wall time: 1min 31s

# %%
new_test.head()
# Out:
#                                   r_item_abyssal_blade  r_item_aegis  \
# 30cc2d778dca82f2edb568ce9b585caa                   0.0           0.0
# 70e5ba30f367cea48793b9003fab9d38                   0.0           0.0
# 4d9ef74d3a2025d79e9423105fd73d41                   0.0           0.0
# 2bb79e0c1eaac1608e5a09c8e0c6a555                   0.0           0.0
# bec17f099b01d67edc82dfb5ce735a43                   0.0           0.0
#
#                                   r_item_aeon_disk  r_item_aether_lens  \
# 30cc2d778dca82f2edb568ce9b585caa               0.0                 0.0
# 70e5ba30f367cea48793b9003fab9d38               0.0                 0.0
# 4d9ef74d3a2025d79e9423105fd73d41               0.0                 0.0
# 2bb79e0c1eaac1608e5a09c8e0c6a555               0.0                 0.0
# bec17f099b01d67edc82dfb5ce735a43               0.0                 0.0
#
#                                   r_item_ancient_janggo  r_item_arcane_boots  \
# 30cc2d778dca82f2edb568ce9b585caa                    0.0                  0.0
# 70e5ba30f367cea48793b9003fab9d38                    1.0                  0.0
# 4d9ef74d3a2025d79e9423105fd73d41                    0.0                  3.0
# 2bb79e0c1eaac1608e5a09c8e0c6a555                    0.0                  1.0
# bec17f099b01d67edc82dfb5ce735a43                    0.0                  0.0
#
#                                   r_item_armlet  r_item_assault  \
# 30cc2d778dca82f2edb568ce9b585caa            0.0             0.0
# 70e5ba30f367cea48793b9003fab9d38            0.0             0.0
# 4d9ef74d3a2025d79e9423105fd73d41            0.0             0.0
# 2bb79e0c1eaac1608e5a09c8e0c6a555            0.0             0.0
# bec17f099b01d67edc82dfb5ce735a43            0.0             0.0
#
#                                   r_item_basher  r_item_belt_of_strength  ...  \
# 30cc2d778dca82f2edb568ce9b585caa            0.0                      0.0  ...
# 70e5ba30f367cea48793b9003fab9d38            0.0                      0.0  ...
# 4d9ef74d3a2025d79e9423105fd73d41            0.0                      0.0  ...
# 2bb79e0c1eaac1608e5a09c8e0c6a555            0.0                      0.0  ...
# bec17f099b01d67edc82dfb5ce735a43            0.0                      0.0  ...
#
#                                   d_item_urn_of_shadows  d_item_vanguard  \
# 30cc2d778dca82f2edb568ce9b585caa                    0.0              0.0
# 70e5ba30f367cea48793b9003fab9d38                    1.0              0.0
# 4d9ef74d3a2025d79e9423105fd73d41                    1.0              0.0
# 2bb79e0c1eaac1608e5a09c8e0c6a555                    0.0              0.0
# bec17f099b01d67edc82dfb5ce735a43                    1.0              0.0
#
#                                   d_item_veil_of_discord  \
# 30cc2d778dca82f2edb568ce9b585caa                     0.0
# 70e5ba30f367cea48793b9003fab9d38                     0.0
# 4d9ef74d3a2025d79e9423105fd73d41                     0.0
# 2bb79e0c1eaac1608e5a09c8e0c6a555                     0.0
# bec17f099b01d67edc82dfb5ce735a43                     0.0
#
#                                   d_item_vitality_booster  d_item_vladmir  \
# 30cc2d778dca82f2edb568ce9b585caa                      0.0             0.0
# 70e5ba30f367cea48793b9003fab9d38                      0.0             0.0
# 4d9ef74d3a2025d79e9423105fd73d41                      0.0             0.0
# 2bb79e0c1eaac1608e5a09c8e0c6a555                      0.0             0.0
# bec17f099b01d67edc82dfb5ce735a43                      1.0             0.0
#
#                                   d_item_void_stone  d_item_ward_dispenser  \
# 30cc2d778dca82f2edb568ce9b585caa                0.0                    0.0
# 70e5ba30f367cea48793b9003fab9d38                0.0                    1.0
# 4d9ef74d3a2025d79e9423105fd73d41                0.0                    0.0
# 2bb79e0c1eaac1608e5a09c8e0c6a555                0.0                    0.0
# bec17f099b01d67edc82dfb5ce735a43                0.0                    0.0
#
#                                   d_item_wind_lace  d_item_wraith_band  \
# 30cc2d778dca82f2edb568ce9b585caa               1.0                 0.0
# 70e5ba30f367cea48793b9003fab9d38               1.0                 0.0
# 4d9ef74d3a2025d79e9423105fd73d41               0.0                 0.0
# 2bb79e0c1eaac1608e5a09c8e0c6a555               0.0                 0.0
# bec17f099b01d67edc82dfb5ce735a43               0.0                 0.0
#
#                                   d_item_yasha
# 30cc2d778dca82f2edb568ce9b585caa           0.0
# 70e5ba30f367cea48793b9003fab9d38           0.0
# 4d9ef74d3a2025d79e9423105fd73d41           0.0
# 2bb79e0c1eaac1608e5a09c8e0c6a555           0.0
# bec17f099b01d67edc82dfb5ce735a43           2.0
#
# [5 rows x 384 columns]

# %%
new_test['match_id_hash']=new_test.index

# %%
new_test.head()
# Out:
#                                   r_item_abyssal_blade  r_item_aegis  \
# 30cc2d778dca82f2edb568ce9b585caa                   0.0           0.0
# 70e5ba30f367cea48793b9003fab9d38                   0.0           0.0
# 4d9ef74d3a2025d79e9423105fd73d41                   0.0           0.0
# 2bb79e0c1eaac1608e5a09c8e0c6a555                   0.0           0.0
# bec17f099b01d67edc82dfb5ce735a43                   0.0           0.0
#
#                                   r_item_aeon_disk  r_item_aether_lens  \
# 30cc2d778dca82f2edb568ce9b585caa               0.0                 0.0
# 70e5ba30f367cea48793b9003fab9d38               0.0                 0.0
# 4d9ef74d3a2025d79e9423105fd73d41               0.0                 0.0
# 2bb79e0c1eaac1608e5a09c8e0c6a555               0.0                 0.0
# bec17f099b01d67edc82dfb5ce735a43               0.0                 0.0
#
#                                   r_item_ancient_janggo  r_item_arcane_boots  \
# 30cc2d778dca82f2edb568ce9b585caa                    0.0                  0.0
# 70e5ba30f367cea48793b9003fab9d38                    1.0                  0.0
# 4d9ef74d3a2025d79e9423105fd73d41                    0.0                  3.0
# 2bb79e0c1eaac1608e5a09c8e0c6a555                    0.0                  1.0
# bec17f099b01d67edc82dfb5ce735a43                    0.0                  0.0
#
#                                   r_item_armlet  r_item_assault  \
# 30cc2d778dca82f2edb568ce9b585caa            0.0             0.0
# 70e5ba30f367cea48793b9003fab9d38            0.0             0.0
# 4d9ef74d3a2025d79e9423105fd73d41            0.0             0.0
# 2bb79e0c1eaac1608e5a09c8e0c6a555            0.0             0.0
# bec17f099b01d67edc82dfb5ce735a43            0.0             0.0
#
#                                   r_item_basher  r_item_belt_of_strength  ...  \
# 30cc2d778dca82f2edb568ce9b585caa            0.0                      0.0  ...
# 70e5ba30f367cea48793b9003fab9d38            0.0                      0.0  ...
# 4d9ef74d3a2025d79e9423105fd73d41            0.0                      0.0  ...
# 2bb79e0c1eaac1608e5a09c8e0c6a555            0.0                      0.0  ...
# bec17f099b01d67edc82dfb5ce735a43            0.0                      0.0  ...
#
#                                   d_item_vanguard  d_item_veil_of_discord  \
# 30cc2d778dca82f2edb568ce9b585caa              0.0                     0.0
# 70e5ba30f367cea48793b9003fab9d38              0.0                     0.0
# 4d9ef74d3a2025d79e9423105fd73d41              0.0                     0.0
# 2bb79e0c1eaac1608e5a09c8e0c6a555              0.0                     0.0
# bec17f099b01d67edc82dfb5ce735a43              0.0                     0.0
#
#                                   d_item_vitality_booster  d_item_vladmir  \
# 30cc2d778dca82f2edb568ce9b585caa                      0.0             0.0
# 70e5ba30f367cea48793b9003fab9d38                      0.0             0.0
# 4d9ef74d3a2025d79e9423105fd73d41                      0.0             0.0
# 2bb79e0c1eaac1608e5a09c8e0c6a555                      0.0             0.0
# bec17f099b01d67edc82dfb5ce735a43                      1.0             0.0
#
#                                   d_item_void_stone  d_item_ward_dispenser  \
# 30cc2d778dca82f2edb568ce9b585caa                0.0                    0.0
# 70e5ba30f367cea48793b9003fab9d38                0.0                    1.0
# 4d9ef74d3a2025d79e9423105fd73d41                0.0                    0.0
# 2bb79e0c1eaac1608e5a09c8e0c6a555                0.0                    0.0
# bec17f099b01d67edc82dfb5ce735a43                0.0                    0.0
#
#                                   d_item_wind_lace  d_item_wraith_band  \
# 30cc2d778dca82f2edb568ce9b585caa               1.0                 0.0
# 70e5ba30f367cea48793b9003fab9d38               1.0                 0.0
# 4d9ef74d3a2025d79e9423105fd73d41               0.0                 0.0
# 2bb79e0c1eaac1608e5a09c8e0c6a555               0.0                 0.0
# bec17f099b01d67edc82dfb5ce735a43               0.0                 0.0
#
#                                   d_item_yasha  \
# 30cc2d778dca82f2edb568ce9b585caa           0.0
# 70e5ba30f367cea48793b9003fab9d38           0.0
# 4d9ef74d3a2025d79e9423105fd73d41           0.0
# 2bb79e0c1eaac1608e5a09c8e0c6a555           0.0
# bec17f099b01d67edc82dfb5ce735a43           2.0
#
#                                                      match_id_hash
# 30cc2d778dca82f2edb568ce9b585caa  30cc2d778dca82f2edb568ce9b585caa
# 70e5ba30f367cea48793b9003fab9d38  70e5ba30f367cea48793b9003fab9d38
# 4d9ef74d3a2025d79e9423105fd73d41  4d9ef74d3a2025d79e9423105fd73d41
# 2bb79e0c1eaac1608e5a09c8e0c6a555  2bb79e0c1eaac1608e5a09c8e0c6a555
# bec17f099b01d67edc82dfb5ce735a43  bec17f099b01d67edc82dfb5ce735a43
#
# [5 rows x 385 columns]

# %%
new_test = new_test.reset_index(drop=True)

# %%
new_test = new_test.set_index('match_id_hash')

# %%
#new_test.to_csv('test_items.csv')

# %%
new_train.head()
# Out:
#                                   r_item_abyssal_blade  r_item_aegis  \
# a400b8f29dece5f4d266f49f1ae2e98a                   0.0           0.0
# b9c57c450ce74a2af79c9ce96fac144d                   0.0           0.0
# 6db558535151ea18ca70a6892197db41                   0.0           0.0
# 46a0ddce8f7ed2a8d9bd5edcbb925682                   0.0           0.0
# b1b35ff97723d9b7ade1c9c3cf48f770                   0.0           0.0
#
#                                   r_item_aeon_disk  r_item_aether_lens  \
# a400b8f29dece5f4d266f49f1ae2e98a               0.0                 0.0
# b9c57c450ce74a2af79c9ce96fac144d               0.0                 0.0
# 6db558535151ea18ca70a6892197db41               0.0                 0.0
# 46a0ddce8f7ed2a8d9bd5edcbb925682               0.0                 0.0
# b1b35ff97723d9b7ade1c9c3cf48f770               0.0                 0.0
#
#                                   r_item_ancient_janggo  r_item_arcane_boots  \
# a400b8f29dece5f4d266f49f1ae2e98a                    0.0                  0.0
# b9c57c450ce74a2af79c9ce96fac144d                    1.0                  0.0
# 6db558535151ea18ca70a6892197db41                    0.0                  0.0
# 46a0ddce8f7ed2a8d9bd5edcbb925682                    0.0                  0.0
# b1b35ff97723d9b7ade1c9c3cf48f770                    0.0                  1.0
#
#                                   r_item_armlet  r_item_assault  \
# a400b8f29dece5f4d266f49f1ae2e98a            0.0             0.0
# b9c57c450ce74a2af79c9ce96fac144d            0.0             0.0
# 6db558535151ea18ca70a6892197db41            0.0             0.0
# 46a0ddce8f7ed2a8d9bd5edcbb925682            0.0             0.0
# b1b35ff97723d9b7ade1c9c3cf48f770            0.0             0.0
#
#                                   r_item_basher  r_item_belt_of_strength  ...  \
# a400b8f29dece5f4d266f49f1ae2e98a            0.0                      0.0  ...
# b9c57c450ce74a2af79c9ce96fac144d            0.0                      0.0  ...
# 6db558535151ea18ca70a6892197db41            0.0                      0.0  ...
# 46a0ddce8f7ed2a8d9bd5edcbb925682            0.0                      0.0  ...
# b1b35ff97723d9b7ade1c9c3cf48f770            0.0                      0.0  ...
#
#                                   d_item_urn_of_shadows  d_item_vanguard  \
# a400b8f29dece5f4d266f49f1ae2e98a                    0.0              0.0
# b9c57c450ce74a2af79c9ce96fac144d                    0.0              0.0
# 6db558535151ea18ca70a6892197db41                    0.0              0.0
# 46a0ddce8f7ed2a8d9bd5edcbb925682                    0.0              0.0
# b1b35ff97723d9b7ade1c9c3cf48f770                    0.0              0.0
#
#                                   d_item_veil_of_discord  \
# a400b8f29dece5f4d266f49f1ae2e98a                     0.0
# b9c57c450ce74a2af79c9ce96fac144d                     0.0
# 6db558535151ea18ca70a6892197db41                     0.0
# 46a0ddce8f7ed2a8d9bd5edcbb925682                     0.0
# b1b35ff97723d9b7ade1c9c3cf48f770                     0.0
#
#                                   d_item_vitality_booster  d_item_vladmir  \
# a400b8f29dece5f4d266f49f1ae2e98a                      0.0             0.0
# b9c57c450ce74a2af79c9ce96fac144d                      0.0             0.0
# 6db558535151ea18ca70a6892197db41                      0.0             0.0
# 46a0ddce8f7ed2a8d9bd5edcbb925682                      0.0             0.0
# b1b35ff97723d9b7ade1c9c3cf48f770                      0.0             0.0
#
#                                   d_item_void_stone  d_item_ward_dispenser  \
# a400b8f29dece5f4d266f49f1ae2e98a                0.0                    0.0
# b9c57c450ce74a2af79c9ce96fac144d                0.0                    0.0
# 6db558535151ea18ca70a6892197db41                0.0                    0.0
# 46a0ddce8f7ed2a8d9bd5edcbb925682                1.0                    0.0
# b1b35ff97723d9b7ade1c9c3cf48f770                0.0                    0.0
#
#                                   d_item_wind_lace  d_item_wraith_band  \
# a400b8f29dece5f4d266f49f1ae2e98a               0.0                 0.0
# b9c57c450ce74a2af79c9ce96fac144d               0.0                 1.0
# 6db558535151ea18ca70a6892197db41               0.0                 1.0
# 46a0ddce8f7ed2a8d9bd5edcbb925682               0.0                 0.0
# b1b35ff97723d9b7ade1c9c3cf48f770               0.0                 0.0
#
#                                   d_item_yasha
# a400b8f29dece5f4d266f49f1ae2e98a           0.0
# b9c57c450ce74a2af79c9ce96fac144d           0.0
# 6db558535151ea18ca70a6892197db41           0.0
# 46a0ddce8f7ed2a8d9bd5edcbb925682           0.0
# b1b35ff97723d9b7ade1c9c3cf48f770           0.0
#
# [5 rows x 384 columns]

# %%
new_train['match_id_hash']=new_train.index

# %%
new_train = new_train.set_index('match_id_hash')

# %%
new_train.head()
# Out:
#                                   r_item_abyssal_blade  r_item_aegis  \
# match_id_hash
# a400b8f29dece5f4d266f49f1ae2e98a                   0.0           0.0
# b9c57c450ce74a2af79c9ce96fac144d                   0.0           0.0
# 6db558535151ea18ca70a6892197db41                   0.0           0.0
# 46a0ddce8f7ed2a8d9bd5edcbb925682                   0.0           0.0
# b1b35ff97723d9b7ade1c9c3cf48f770                   0.0           0.0
#
#                                   r_item_aeon_disk  r_item_aether_lens  \
# match_id_hash
# a400b8f29dece5f4d266f49f1ae2e98a               0.0                 0.0
# b9c57c450ce74a2af79c9ce96fac144d               0.0                 0.0
# 6db558535151ea18ca70a6892197db41               0.0                 0.0
# 46a0ddce8f7ed2a8d9bd5edcbb925682               0.0                 0.0
# b1b35ff97723d9b7ade1c9c3cf48f770               0.0                 0.0
#
#                                   r_item_ancient_janggo  r_item_arcane_boots  \
# match_id_hash
# a400b8f29dece5f4d266f49f1ae2e98a                    0.0                  0.0
# b9c57c450ce74a2af79c9ce96fac144d                    1.0                  0.0
# 6db558535151ea18ca70a6892197db41                    0.0                  0.0
# 46a0ddce8f7ed2a8d9bd5edcbb925682                    0.0                  0.0
# b1b35ff97723d9b7ade1c9c3cf48f770                    0.0                  1.0
#
#                                   r_item_armlet  r_item_assault  \
# match_id_hash
# a400b8f29dece5f4d266f49f1ae2e98a            0.0             0.0
# b9c57c450ce74a2af79c9ce96fac144d            0.0             0.0
# 6db558535151ea18ca70a6892197db41            0.0             0.0
# 46a0ddce8f7ed2a8d9bd5edcbb925682            0.0             0.0
# b1b35ff97723d9b7ade1c9c3cf48f770            0.0             0.0
#
#                                   r_item_basher  r_item_belt_of_strength  ...  \
# match_id_hash                                                             ...
# a400b8f29dece5f4d266f49f1ae2e98a            0.0                      0.0  ...
# b9c57c450ce74a2af79c9ce96fac144d            0.0                      0.0  ...
# 6db558535151ea18ca70a6892197db41            0.0                      0.0  ...
# 46a0ddce8f7ed2a8d9bd5edcbb925682            0.0                      0.0  ...
# b1b35ff97723d9b7ade1c9c3cf48f770            0.0                      0.0  ...
#
#                                   d_item_urn_of_shadows  d_item_vanguard  \
# match_id_hash
# a400b8f29dece5f4d266f49f1ae2e98a                    0.0              0.0
# b9c57c450ce74a2af79c9ce96fac144d                    0.0              0.0
# 6db558535151ea18ca70a6892197db41                    0.0              0.0
# 46a0ddce8f7ed2a8d9bd5edcbb925682                    0.0              0.0
# b1b35ff97723d9b7ade1c9c3cf48f770                    0.0              0.0
#
#                                   d_item_veil_of_discord  \
# match_id_hash
# a400b8f29dece5f4d266f49f1ae2e98a                     0.0
# b9c57c450ce74a2af79c9ce96fac144d                     0.0
# 6db558535151ea18ca70a6892197db41                     0.0
# 46a0ddce8f7ed2a8d9bd5edcbb925682                     0.0
# b1b35ff97723d9b7ade1c9c3cf48f770                     0.0
#
#                                   d_item_vitality_booster  d_item_vladmir  \
# match_id_hash
# a400b8f29dece5f4d266f49f1ae2e98a                      0.0             0.0
# b9c57c450ce74a2af79c9ce96fac144d                      0.0             0.0
# 6db558535151ea18ca70a6892197db41                      0.0             0.0
# 46a0ddce8f7ed2a8d9bd5edcbb925682                      0.0             0.0
# b1b35ff97723d9b7ade1c9c3cf48f770                      0.0             0.0
#
#                                   d_item_void_stone  d_item_ward_dispenser  \
# match_id_hash
# a400b8f29dece5f4d266f49f1ae2e98a                0.0                    0.0
# b9c57c450ce74a2af79c9ce96fac144d                0.0                    0.0
# 6db558535151ea18ca70a6892197db41                0.0                    0.0
# 46a0ddce8f7ed2a8d9bd5edcbb925682                1.0                    0.0
# b1b35ff97723d9b7ade1c9c3cf48f770                0.0                    0.0
#
#                                   d_item_wind_lace  d_item_wraith_band  \
# match_id_hash
# a400b8f29dece5f4d266f49f1ae2e98a               0.0                 0.0
# b9c57c450ce74a2af79c9ce96fac144d               0.0                 1.0
# 6db558535151ea18ca70a6892197db41               0.0                 1.0
# 46a0ddce8f7ed2a8d9bd5edcbb925682               0.0                 0.0
# b1b35ff97723d9b7ade1c9c3cf48f770               0.0                 0.0
#
#                                   d_item_yasha
# match_id_hash
# a400b8f29dece5f4d266f49f1ae2e98a           0.0
# b9c57c450ce74a2af79c9ce96fac144d           0.0
# 6db558535151ea18ca70a6892197db41           0.0
# 46a0ddce8f7ed2a8d9bd5edcbb925682           0.0
# b1b35ff97723d9b7ade1c9c3cf48f770           0.0
#
# [5 rows x 384 columns]

# %%
#new_train.to_csv('train_items.csv')

# %%
def add_new_features(df_features, matches_file):
    
    # Process raw data and add new features
    for match in read_matches(matches_file):
        match_id_hash = match['match_id_hash']

        # Counting ruined towers for both teams
        radiant_tower_kills = 0
        dire_tower_kills = 0
        for objective in match['objectives']:
            if objective['type'] == 'CHAT_MESSAGE_TOWER_KILL':
                if objective['team'] == 2:
                    radiant_tower_kills += 1
                if objective['team'] == 3:
                    dire_tower_kills += 1

        # Write new features
        df_features.loc[match_id_hash, 'radiant_tower_kills'] = radiant_tower_kills
        df_features.loc[match_id_hash, 'dire_tower_kills'] = dire_tower_kills
        df_features.loc[match_id_hash, 'diff_tower_kills'] = radiant_tower_kills - dire_tower_kills
        
        # Total damage
        total_damage = 0
        for i in range(1, 6):
            for j in match['players'][i-1]['damage']:
                # Take damage only to hero(not for creeps)
                if j.startswith('npc_dota_hero'):
                    total_damage += match['players'][i-1]['damage'][j]
        df_features.loc[match_id_hash, 'r_damage'] = total_damage
        total_damage = 0
        for i in range(6, 11):
            for j in match['players'][i-1]['damage']:
                if j.startswith('npc_dota_hero'):
                    total_damage += match['players'][i-1]['damage'][j]
        df_features.loc[match_id_hash, 'd_damage'] = total_damage

        df_features.loc[match_id_hash, 'diff_damage'] = df_features.loc[match_id_hash, 'r_damage'] - df_features.loc[match_id_hash, 'd_damage']

# %%
# %%time
# copy the dataframe with features
df_train_features_extended = new_train.copy()

# add new features
add_new_features(df_train_features_extended, os.path.join(PATH_TO_DATA, 'train_matches.jsonl'))
# Out:
# HBox(children=(IntProgress(value=0, max=39675), HTML(value='')))
# Wall time: 1min 13s

# %%
df_train_features_extended.head()
# Out:
#                                   r_item_abyssal_blade  r_item_aegis  \
# match_id_hash
# a400b8f29dece5f4d266f49f1ae2e98a                   0.0           0.0
# b9c57c450ce74a2af79c9ce96fac144d                   0.0           0.0
# 6db558535151ea18ca70a6892197db41                   0.0           0.0
# 46a0ddce8f7ed2a8d9bd5edcbb925682                   0.0           0.0
# b1b35ff97723d9b7ade1c9c3cf48f770                   0.0           0.0
#
#                                   r_item_aeon_disk  r_item_aether_lens  \
# match_id_hash
# a400b8f29dece5f4d266f49f1ae2e98a               0.0                 0.0
# b9c57c450ce74a2af79c9ce96fac144d               0.0                 0.0
# 6db558535151ea18ca70a6892197db41               0.0                 0.0
# 46a0ddce8f7ed2a8d9bd5edcbb925682               0.0                 0.0
# b1b35ff97723d9b7ade1c9c3cf48f770               0.0                 0.0
#
#                                   r_item_ancient_janggo  r_item_arcane_boots  \
# match_id_hash
# a400b8f29dece5f4d266f49f1ae2e98a                    0.0                  0.0
# b9c57c450ce74a2af79c9ce96fac144d                    1.0                  0.0
# 6db558535151ea18ca70a6892197db41                    0.0                  0.0
# 46a0ddce8f7ed2a8d9bd5edcbb925682                    0.0                  0.0
# b1b35ff97723d9b7ade1c9c3cf48f770                    0.0                  1.0
#
#                                   r_item_armlet  r_item_assault  \
# match_id_hash
# a400b8f29dece5f4d266f49f1ae2e98a            0.0             0.0
# b9c57c450ce74a2af79c9ce96fac144d            0.0             0.0
# 6db558535151ea18ca70a6892197db41            0.0             0.0
# 46a0ddce8f7ed2a8d9bd5edcbb925682            0.0             0.0
# b1b35ff97723d9b7ade1c9c3cf48f770            0.0             0.0
#
#                                   r_item_basher  r_item_belt_of_strength  ...  \
# match_id_hash                                                             ...
# a400b8f29dece5f4d266f49f1ae2e98a            0.0                      0.0  ...
# b9c57c450ce74a2af79c9ce96fac144d            0.0                      0.0  ...
# 6db558535151ea18ca70a6892197db41            0.0                      0.0  ...
# 46a0ddce8f7ed2a8d9bd5edcbb925682            0.0                      0.0  ...
# b1b35ff97723d9b7ade1c9c3cf48f770            0.0                      0.0  ...
#
#                                   d_item_ward_dispenser  d_item_wind_lace  \
# match_id_hash
# a400b8f29dece5f4d266f49f1ae2e98a                    0.0               0.0
# b9c57c450ce74a2af79c9ce96fac144d                    0.0               0.0
# 6db558535151ea18ca70a6892197db41                    0.0               0.0
# 46a0ddce8f7ed2a8d9bd5edcbb925682                    0.0               0.0
# b1b35ff97723d9b7ade1c9c3cf48f770                    0.0               0.0
#
#                                   d_item_wraith_band  d_item_yasha  \
# match_id_hash
# a400b8f29dece5f4d266f49f1ae2e98a                 0.0           0.0
# b9c57c450ce74a2af79c9ce96fac144d                 1.0           0.0
# 6db558535151ea18ca70a6892197db41                 1.0           0.0
# 46a0ddce8f7ed2a8d9bd5edcbb925682                 0.0           0.0
# b1b35ff97723d9b7ade1c9c3cf48f770                 0.0           0.0
#
#                                   radiant_tower_kills  dire_tower_kills  \
# match_id_hash
# a400b8f29dece5f4d266f49f1ae2e98a                  0.0               0.0
# b9c57c450ce74a2af79c9ce96fac144d                  2.0               0.0
# 6db558535151ea18ca70a6892197db41                  0.0               0.0
# 46a0ddce8f7ed2a8d9bd5edcbb925682                  0.0               0.0
# b1b35ff97723d9b7ade1c9c3cf48f770                  0.0               0.0
#
#                                   diff_tower_kills  r_damage  d_damage  \
# match_id_hash
# a400b8f29dece5f4d266f49f1ae2e98a               0.0     948.0    2949.0
# b9c57c450ce74a2af79c9ce96fac144d               2.0   17463.0   13063.0
# 6db558535151ea18ca70a6892197db41               0.0      70.0      68.0
# 46a0ddce8f7ed2a8d9bd5edcbb925682               0.0   15542.0    8337.0
# b1b35ff97723d9b7ade1c9c3cf48f770               0.0    5940.0   11951.0
#
#                                   diff_damage
# match_id_hash
# a400b8f29dece5f4d266f49f1ae2e98a      -2001.0
# b9c57c450ce74a2af79c9ce96fac144d       4400.0
# 6db558535151ea18ca70a6892197db41          2.0
# 46a0ddce8f7ed2a8d9bd5edcbb925682       7205.0
# b1b35ff97723d9b7ade1c9c3cf48f770      -6011.0
#
# [5 rows x 390 columns]

# %%
df_test_features_extended = new_test.copy()

# add new features
add_new_features(df_test_features_extended, os.path.join(PATH_TO_DATA, 'test_matches.jsonl'))
# Out:
# HBox(children=(IntProgress(value=0, max=10000), HTML(value='')))

# %%
df_test_features_extended.head()
# Out:
#                                   r_item_abyssal_blade  r_item_aegis  \
# match_id_hash
# 30cc2d778dca82f2edb568ce9b585caa                   0.0           0.0
# 70e5ba30f367cea48793b9003fab9d38                   0.0           0.0
# 4d9ef74d3a2025d79e9423105fd73d41                   0.0           0.0
# 2bb79e0c1eaac1608e5a09c8e0c6a555                   0.0           0.0
# bec17f099b01d67edc82dfb5ce735a43                   0.0           0.0
#
#                                   r_item_aeon_disk  r_item_aether_lens  \
# match_id_hash
# 30cc2d778dca82f2edb568ce9b585caa               0.0                 0.0
# 70e5ba30f367cea48793b9003fab9d38               0.0                 0.0
# 4d9ef74d3a2025d79e9423105fd73d41               0.0                 0.0
# 2bb79e0c1eaac1608e5a09c8e0c6a555               0.0                 0.0
# bec17f099b01d67edc82dfb5ce735a43               0.0                 0.0
#
#                                   r_item_ancient_janggo  r_item_arcane_boots  \
# match_id_hash
# 30cc2d778dca82f2edb568ce9b585caa                    0.0                  0.0
# 70e5ba30f367cea48793b9003fab9d38                    1.0                  0.0
# 4d9ef74d3a2025d79e9423105fd73d41                    0.0                  3.0
# 2bb79e0c1eaac1608e5a09c8e0c6a555                    0.0                  1.0
# bec17f099b01d67edc82dfb5ce735a43                    0.0                  0.0
#
#                                   r_item_armlet  r_item_assault  \
# match_id_hash
# 30cc2d778dca82f2edb568ce9b585caa            0.0             0.0
# 70e5ba30f367cea48793b9003fab9d38            0.0             0.0
# 4d9ef74d3a2025d79e9423105fd73d41            0.0             0.0
# 2bb79e0c1eaac1608e5a09c8e0c6a555            0.0             0.0
# bec17f099b01d67edc82dfb5ce735a43            0.0             0.0
#
#                                   r_item_basher  r_item_belt_of_strength  ...  \
# match_id_hash                                                             ...
# 30cc2d778dca82f2edb568ce9b585caa            0.0                      0.0  ...
# 70e5ba30f367cea48793b9003fab9d38            0.0                      0.0  ...
# 4d9ef74d3a2025d79e9423105fd73d41            0.0                      0.0  ...
# 2bb79e0c1eaac1608e5a09c8e0c6a555            0.0                      0.0  ...
# bec17f099b01d67edc82dfb5ce735a43            0.0                      0.0  ...
#
#                                   d_item_ward_dispenser  d_item_wind_lace  \
# match_id_hash
# 30cc2d778dca82f2edb568ce9b585caa                    0.0               1.0
# 70e5ba30f367cea48793b9003fab9d38                    1.0               1.0
# 4d9ef74d3a2025d79e9423105fd73d41                    0.0               0.0
# 2bb79e0c1eaac1608e5a09c8e0c6a555                    0.0               0.0
# bec17f099b01d67edc82dfb5ce735a43                    0.0               0.0
#
#                                   d_item_wraith_band  d_item_yasha  \
# match_id_hash
# 30cc2d778dca82f2edb568ce9b585caa                 0.0           0.0
# 70e5ba30f367cea48793b9003fab9d38                 0.0           0.0
# 4d9ef74d3a2025d79e9423105fd73d41                 0.0           0.0
# 2bb79e0c1eaac1608e5a09c8e0c6a555                 0.0           0.0
# bec17f099b01d67edc82dfb5ce735a43                 0.0           2.0
#
#                                   radiant_tower_kills  dire_tower_kills  \
# match_id_hash
# 30cc2d778dca82f2edb568ce9b585caa                  0.0               0.0
# 70e5ba30f367cea48793b9003fab9d38                  7.0               2.0
# 4d9ef74d3a2025d79e9423105fd73d41                  4.0               1.0
# 2bb79e0c1eaac1608e5a09c8e0c6a555                  0.0               0.0
# bec17f099b01d67edc82dfb5ce735a43                  2.0               4.0
#
#                                   diff_tower_kills  r_damage  d_damage  \
# match_id_hash
# 30cc2d778dca82f2edb568ce9b585caa               0.0     719.0     281.0
# 70e5ba30f367cea48793b9003fab9d38               5.0   39019.0   34237.0
# 4d9ef74d3a2025d79e9423105fd73d41               3.0   36831.0   27318.0
# 2bb79e0c1eaac1608e5a09c8e0c6a555               0.0   15281.0   16531.0
# bec17f099b01d67edc82dfb5ce735a43              -2.0   46854.0   57564.0
#
#                                   diff_damage
# match_id_hash
# 30cc2d778dca82f2edb568ce9b585caa        438.0
# 70e5ba30f367cea48793b9003fab9d38       4782.0
# 4d9ef74d3a2025d79e9423105fd73d41       9513.0
# 2bb79e0c1eaac1608e5a09c8e0c6a555      -1250.0
# bec17f099b01d67edc82dfb5ce735a43     -10710.0
#
# [5 rows x 390 columns]

# %%
df_train_features_extended.shape, df_test_features_extended.shape
# Out:
# ((39675, 390), (10000, 390))

# %%
new_features = pd.concat([df_train_features_extended, df_test_features_extended])

# %%
new_features.shape
# Out:
# (49675, 390)

# %%
new_features.to_csv('new_features.csv')
